# %%
import pandas as pd
import datetime as datetime
import matplotlib as mpl
import plotly.graph_objects as go
import dash
import requests
import json

import numpy as np
from sklearn import linear_model
from scipy import signal
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# %%
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (16, 9)
pd.set_option('display.max_rows', 500)

# %%
data_dir='../data/processed/Cases_pop.csv'
df_list=pd.read_csv(data_dir, sep=';')

# %%
#country_list = ['AUS', 'USA', 'ESP', 'IND', 'CHN', 'DEU', 'AFG']

# %%
# Requesting the Covid Cases data from our world in data website as a json object.
data_cases = requests.get(
    'https://covid.ourworldindata.org/data/owid-covid-data.json')
# load json object for the total number of COVID cases
json_object_cases = json.loads(data_cases.content)

countries_list = list(json_object_cases.keys())
country_remove=['OWID_INT','OWID_CYN']
country_list=list(set(countries_list) - set(country_remove))

# %%
df_small=df_list[['date','Cases_per_pop_AUS', 'Cases_per_pop_USA', 'Cases_per_pop_ESP', 'Cases_per_pop_IND', 'Cases_per_pop_CHN', 'Cases_per_pop_DEU', 'Cases_per_pop_AFG']]
df_small
# Out:
#            date  Cases_per_pop_AUS  Cases_per_pop_USA  Cases_per_pop_ESP  \
# 0    2020-01-01           0.045585           0.101435           0.092299
# 1    2020-01-02           0.045585           0.101435           0.092299
# 2    2020-01-03           0.045585           0.101435           0.092299
# 3    2020-01-04           0.045585           0.101435           0.092299
# 4    2020-01-05           0.045585           0.101435           0.092299
# ..          ...                ...                ...                ...
# 929  2022-07-18           0.341932           0.266210           0.275665
# 930  2022-07-19           0.343818           0.266561           0.276543
# 931  2022-07-20           0.345940           0.267201           0.276543
# 932  2022-07-21           0.347939           0.267659           0.276543
# 933  2022-07-22           0.349726           0.268153           0.278074
#
#      Cases_per_pop_IND  Cases_per_pop_CHN  Cases_per_pop_DEU  \
# 0             0.014822           0.000129           0.073985
# 1             0.014822           0.000129           0.073985
# 2             0.014822           0.000129           0.073985
# 3             0.014822           0.000129           0.073985
# 4             0.014822           0.000129           0.073985
# ..                 ...                ...                ...
# 929           0.031106           0.000629           0.357921
# 930           0.031119           0.000629           0.359612
# 931           0.031135           0.000630           0.361250
# 932           0.031151           0.000630           0.362542
# 933           0.031166           0.000631           0.363645
#
#      Cases_per_pop_AFG
# 0             0.002368
# 1             0.002368
# 2             0.002368
# 3             0.002368
# 4             0.002368
# ..                 ...
# 929           0.004581
# 930           0.004586
# 931           0.004590
# 932           0.004594
# 933           0.004598
#
# [934 rows x 8 columns]

# %% [markdown]
# # Helper Function

# %%
def quick_plot(x_in, df_input, y_scale='log', slider=False):
    """ Quick basic plot for quick static evaluation of a time series

        you can push selective columns of your data frame by .iloc[:,[0,6,7,8]]

        Parameters:
        ----------
        x_in : array 
            array of date time object, or array of numbers
        df_input : pandas dataframe 
            the plotting matrix where each column is plotted
            the name of the column will be used for the legend
        scale: str
            y-axis scale as 'log' or 'linear'
        slider: bool
            True or False for x-axis slider


        Returns:
        ----------

    """
    fig = go.Figure()

    for each in df_input.columns:
        fig.add_trace(
            go.Scatter(x=x_in, y=df_input[each], name=each, opacity=0.8))

    fig.update_layout(autosize=True,
                      width=1024,
                      height=768,
                      font=dict(family="PT Sans, monospace",
                                size=18,
                                color="#7f7f7f"))
    fig.update_yaxes(type=y_scale),
    fig.update_xaxes(tickangle=-45,
                     nticks=20,
                     tickfont=dict(size=14, color="#7f7f7f"))
    if slider == True:
        fig.update_layout(xaxis_rangeslider_visible=True)
    fig.show()

# %% [markdown]
# # Understanding Linear Regression

# %%
data_dir='../data/processed/Cases_pop_NoNaN.csv'
df_list=pd.read_csv(data_dir, sep=';')

# %%
reg = linear_model.LinearRegression(fit_intercept=True)

# %%
df_per=pd.concat([df_list['date'], (df_list.iloc[:,1:]*100)])

# %%
df_per.reset_index().drop(columns='index').rename(columns={0:'date'})
# Out:
#             date  Cases_per_pop_DOM  Cases_per_pop_KWT  Cases_per_pop_MUS  \
# 0     2020-01-01                NaN                NaN                NaN
# 1     2020-01-02                NaN                NaN                NaN
# 2     2020-01-03                NaN                NaN                NaN
# 3     2020-01-04                NaN                NaN                NaN
# 4     2020-01-05                NaN                NaN                NaN
# ...          ...                ...                ...                ...
# 1863         NaN           5.598480          15.251732          18.219129
# 1864         NaN           5.604534          15.251732          18.219129
# 1865         NaN           5.614086          15.251732          18.219129
# 1866         NaN           5.614086          15.251732          18.219129
# 1867         NaN           5.622982          15.353494          18.219129
#
#       Cases_per_pop_BTN  Cases_per_pop_GMB  Cases_per_pop_KIR  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 1863             7.7312           0.454901           2.510980
# 1864             7.7312           0.455621           2.510980
# 1865             7.7312           0.455621           2.510980
# 1866             7.7312           0.455621           2.597886
# 1867             7.7312           0.455621           2.597886
#
#       Cases_per_pop_MYS  Cases_per_pop_MMR  Cases_per_pop_NGA  ...  \
# 0                   NaN                NaN                NaN  ...
# 1                   NaN                NaN                NaN  ...
# 2                   NaN                NaN                NaN  ...
# 3                   NaN                NaN                NaN  ...
# 4                   NaN                NaN                NaN  ...
# ...                 ...                ...                ...  ...
# 1863          13.778752           1.141003           0.121371  ...
# 1864          13.790375           1.141035           0.121595  ...
# 1865          13.807307           1.141065           0.121595  ...
# 1866          13.820970           1.141095           0.121705  ...
# 1867          13.832526           1.141113           0.121705  ...
#
#       Cases_per_pop_PRK  Cases_per_pop_MCO  Cases_per_pop_FRO  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 1863           0.000004          37.559287          65.530933
# 1864           0.000004          37.739192          65.530933
# 1865           0.000004          37.853677          65.530933
# 1866           0.000004          37.927275          65.530933
# 1867           0.000004          38.063566          65.530933
#
#       Cases_per_pop_ESP  Cases_per_pop_SMR  Cases_per_pop_ISR  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 1863          27.566479          57.052688          48.633161
# 1864          27.654257          57.349019          48.707803
# 1865          27.654257          57.550525          48.774954
# 1866          27.654257          57.707580          48.841868
# 1867          27.807360          57.879452          48.906307
#
#       Cases_per_pop_SVK  Cases_per_pop_MLI  Cases_per_pop_POL  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 1863          47.078028           0.142447          15.748244
# 1864          47.107068           0.142447          15.756722
# 1865          47.135723           0.142456          15.764165
# 1866          47.162046           0.142470          15.771991
# 1867          47.187231           0.142470          15.779906
#
#       Cases_per_pop_LBY
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 1863           7.462826
# 1864           7.462826
# 1865           7.462826
# 1866           7.462826
# 1867           7.462826
#
# [1868 rows x 243 columns]

# %%
df_per[0] = pd.to_datetime(df_per[0], format='%Y-%m-%d')
df_per.rename(columns={0:'date'})
# Out:
#           date  Cases_per_pop_DOM  Cases_per_pop_KWT  Cases_per_pop_MUS  \
# 0   2020-01-01                NaN                NaN                NaN
# 1   2020-01-02                NaN                NaN                NaN
# 2   2020-01-03                NaN                NaN                NaN
# 3   2020-01-04                NaN                NaN                NaN
# 4   2020-01-05                NaN                NaN                NaN
# ..         ...                ...                ...                ...
# 929        NaT           5.598480          15.251732          18.219129
# 930        NaT           5.604534          15.251732          18.219129
# 931        NaT           5.614086          15.251732          18.219129
# 932        NaT           5.614086          15.251732          18.219129
# 933        NaT           5.622982          15.353494          18.219129
#
#      Cases_per_pop_BTN  Cases_per_pop_GMB  Cases_per_pop_KIR  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 929             7.7312           0.454901           2.510980
# 930             7.7312           0.455621           2.510980
# 931             7.7312           0.455621           2.510980
# 932             7.7312           0.455621           2.597886
# 933             7.7312           0.455621           2.597886
#
#      Cases_per_pop_MYS  Cases_per_pop_MMR  Cases_per_pop_NGA  ...  \
# 0                  NaN                NaN                NaN  ...
# 1                  NaN                NaN                NaN  ...
# 2                  NaN                NaN                NaN  ...
# 3                  NaN                NaN                NaN  ...
# 4                  NaN                NaN                NaN  ...
# ..                 ...                ...                ...  ...
# 929          13.778752           1.141003           0.121371  ...
# 930          13.790375           1.141035           0.121595  ...
# 931          13.807307           1.141065           0.121595  ...
# 932          13.820970           1.141095           0.121705  ...
# 933          13.832526           1.141113           0.121705  ...
#
#      Cases_per_pop_PRK  Cases_per_pop_MCO  Cases_per_pop_FRO  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 929           0.000004          37.559287          65.530933
# 930           0.000004          37.739192          65.530933
# 931           0.000004          37.853677          65.530933
# 932           0.000004          37.927275          65.530933
# 933           0.000004          38.063566          65.530933
#
#      Cases_per_pop_ESP  Cases_per_pop_SMR  Cases_per_pop_ISR  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 929          27.566479          57.052688          48.633161
# 930          27.654257          57.349019          48.707803
# 931          27.654257          57.550525          48.774954
# 932          27.654257          57.707580          48.841868
# 933          27.807360          57.879452          48.906307
#
#      Cases_per_pop_SVK  Cases_per_pop_MLI  Cases_per_pop_POL  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 929          47.078028           0.142447          15.748244
# 930          47.107068           0.142447          15.756722
# 931          47.135723           0.142456          15.764165
# 932          47.162046           0.142470          15.771991
# 933          47.187231           0.142470          15.779906
#
#      Cases_per_pop_LBY
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 929           7.462826
# 930           7.462826
# 931           7.462826
# 932           7.462826
# 933           7.462826
#
# [1868 rows x 243 columns]

# %%
df_per.dtypes
# Out:
# 0                         datetime64[ns]
# Cases_per_pop_DOM                float64
# Cases_per_pop_KWT                float64
# Cases_per_pop_MUS                float64
# Cases_per_pop_BTN                float64
# Cases_per_pop_GMB                float64
# Cases_per_pop_KIR                float64
# Cases_per_pop_MYS                float64
# Cases_per_pop_MMR                float64
# Cases_per_pop_NGA                float64
# Cases_per_pop_ATG                float64
# Cases_per_pop_TUR                float64
# Cases_per_pop_LKA                float64
# Cases_per_pop_OWID_ASI           float64
# Cases_per_pop_NAM                float64
# Cases_per_pop_CMR                float64
# Cases_per_pop_CRI                float64
# Cases_per_pop_PYF                float64
# Cases_per_pop_ECU                float64
# Cases_per_pop_TON                float64
# Cases_per_pop_CIV                float64
# Cases_per_pop_HTI                float64
# Cases_per_pop_MAR                float64
# Cases_per_pop_PRY                float64
# Cases_per_pop_OWID_SAM           float64
# Cases_per_pop_SYR                float64
# Cases_per_pop_AND                float64
# Cases_per_pop_PRT                float64
# Cases_per_pop_SEN                float64
# Cases_per_pop_SPM                float64
# Cases_per_pop_NIU                float64
# Cases_per_pop_TZA                float64
# Cases_per_pop_KHM                float64
# Cases_per_pop_MKD                float64
# Cases_per_pop_OWID_KOS           float64
# Cases_per_pop_GBR                float64
# Cases_per_pop_KAZ                float64
# Cases_per_pop_NZL                float64
# Cases_per_pop_TCD                float64
# Cases_per_pop_IRQ                float64
# Cases_per_pop_CHE                float64
# Cases_per_pop_RUS                float64
# Cases_per_pop_PAK                float64
# Cases_per_pop_KEN                float64
# Cases_per_pop_SXM                float64
# Cases_per_pop_NPL                float64
# Cases_per_pop_AUS                float64
# Cases_per_pop_COL                float64
# Cases_per_pop_COM                float64
# Cases_per_pop_MWI                float64
# Cases_per_pop_LIE                float64
# Cases_per_pop_VNM                float64
# Cases_per_pop_DJI                float64
# Cases_per_pop_GRL                float64
# Cases_per_pop_EGY                float64
# Cases_per_pop_NRU                float64
# Cases_per_pop_ARM                float64
# Cases_per_pop_ABW                float64
# Cases_per_pop_SSD                float64
# Cases_per_pop_IDN                float64
# Cases_per_pop_AGO                float64
# Cases_per_pop_OWID_OCE           float64
# Cases_per_pop_COK                float64
# Cases_per_pop_GIN                float64
# Cases_per_pop_LBR                float64
# Cases_per_pop_STP                float64
# Cases_per_pop_BEL                float64
# Cases_per_pop_BGD                float64
# Cases_per_pop_OWID_EUN           float64
# Cases_per_pop_KGZ                float64
# Cases_per_pop_SAU                float64
# Cases_per_pop_CYM                float64
# Cases_per_pop_DEU                float64
# Cases_per_pop_CYP                float64
# Cases_per_pop_SLB                float64
# Cases_per_pop_OWID_UMC           float64
# Cases_per_pop_BDI                float64
# Cases_per_pop_NER                float64
# Cases_per_pop_DNK                float64
# Cases_per_pop_ARG                float64
# Cases_per_pop_LAO                float64
# Cases_per_pop_OWID_HIC           float64
# Cases_per_pop_UZB                float64
# Cases_per_pop_FIN                float64
# Cases_per_pop_MAC                float64
# Cases_per_pop_ITA                float64
# Cases_per_pop_LCA                float64
# Cases_per_pop_OWID_LIC           float64
# Cases_per_pop_PSE                float64
# Cases_per_pop_SLV                float64
# Cases_per_pop_ERI                float64
# Cases_per_pop_MEX                float64
# Cases_per_pop_TLS                float64
# Cases_per_pop_HKG                float64
# Cases_per_pop_ALB                float64
# Cases_per_pop_MDV                float64
# Cases_per_pop_IRL                float64
# Cases_per_pop_ARE                float64
# Cases_per_pop_GHA                float64
# Cases_per_pop_LTU                float64
# Cases_per_pop_AFG                float64
# Cases_per_pop_MLT                float64
# Cases_per_pop_NCL                float64
# Cases_per_pop_PHL                float64
# Cases_per_pop_JAM                float64
# Cases_per_pop_CAN                float64
# Cases_per_pop_IRN                float64
# Cases_per_pop_SHN                float64
# Cases_per_pop_GUM                float64
# Cases_per_pop_ZAF                float64
# Cases_per_pop_DZA                float64
# Cases_per_pop_TTO                float64
# Cases_per_pop_BRB                float64
# Cases_per_pop_FJI                float64
# Cases_per_pop_GAB                float64
# Cases_per_pop_MRT                float64
# Cases_per_pop_UGA                float64
# Cases_per_pop_VEN                float64
# Cases_per_pop_ESH                float64
# Cases_per_pop_SWE                float64
# Cases_per_pop_TWN                float64
# Cases_per_pop_JOR                float64
# Cases_per_pop_SDN                float64
# Cases_per_pop_VUT                float64
# Cases_per_pop_FRA                float64
# Cases_per_pop_MHL                float64
# Cases_per_pop_PCN                float64
# Cases_per_pop_SYC                float64
# Cases_per_pop_PER                float64
# Cases_per_pop_CAF                float64
# Cases_per_pop_BGR                float64
# Cases_per_pop_MDA                float64
# Cases_per_pop_BRN                float64
# Cases_per_pop_BRA                float64
# Cases_per_pop_VGB                float64
# Cases_per_pop_MOZ                float64
# Cases_per_pop_NIC                float64
# Cases_per_pop_PLW                float64
# Cases_per_pop_WSM                float64
# Cases_per_pop_OMN                float64
# Cases_per_pop_BFA                float64
# Cases_per_pop_TGO                float64
# Cases_per_pop_BHS                float64
# Cases_per_pop_GRC                float64
# Cases_per_pop_SVN                float64
# Cases_per_pop_BMU                float64
# Cases_per_pop_IMN                float64
# Cases_per_pop_MNP                float64
# Cases_per_pop_MSR                float64
# Cases_per_pop_BLR                float64
# Cases_per_pop_KNA                float64
# Cases_per_pop_IND                float64
# Cases_per_pop_GIB                float64
# Cases_per_pop_FSM                float64
# Cases_per_pop_MNG                float64
# Cases_per_pop_GTM                float64
# Cases_per_pop_HND                float64
# Cases_per_pop_BWA                float64
# Cases_per_pop_OWID_AFR           float64
# Cases_per_pop_WLF                float64
# Cases_per_pop_USA                float64
# Cases_per_pop_AIA                float64
# Cases_per_pop_EST                float64
# Cases_per_pop_ETH                float64
# Cases_per_pop_QAT                float64
# Cases_per_pop_CUW                float64
# Cases_per_pop_TJK                float64
# Cases_per_pop_CHN                float64
# Cases_per_pop_YEM                float64
# Cases_per_pop_UKR                float64
# Cases_per_pop_BEN                float64
# Cases_per_pop_CHL                float64
# Cases_per_pop_ISL                float64
# Cases_per_pop_ZMB                float64
# Cases_per_pop_THA                float64
# Cases_per_pop_BHR                float64
# Cases_per_pop_URY                float64
# Cases_per_pop_COD                float64
# Cases_per_pop_SWZ                float64
# Cases_per_pop_TKM                float64
# Cases_per_pop_GNB                float64
# Cases_per_pop_BOL                float64
# Cases_per_pop_LBN                float64
# Cases_per_pop_NOR                float64
# Cases_per_pop_TCA                float64
# Cases_per_pop_OWID_NAM           float64
# Cases_per_pop_TKL                float64
# Cases_per_pop_PAN                float64
# Cases_per_pop_SUR                float64
# Cases_per_pop_ZWE                float64
# Cases_per_pop_COG                float64
# Cases_per_pop_MNE                float64
# Cases_per_pop_VCT                float64
# Cases_per_pop_GEO                float64
# Cases_per_pop_GNQ                float64
# Cases_per_pop_SOM                float64
# Cases_per_pop_CPV                float64
# Cases_per_pop_OWID_LMC           float64
# Cases_per_pop_RWA                float64
# Cases_per_pop_PRI                float64
# Cases_per_pop_FLK                float64
# Cases_per_pop_SRB                float64
# Cases_per_pop_MDG                float64
# Cases_per_pop_CZE                float64
# Cases_per_pop_VAT                float64
# Cases_per_pop_OWID_WRL           float64
# Cases_per_pop_GRD                float64
# Cases_per_pop_HRV                float64
# Cases_per_pop_NLD                float64
# Cases_per_pop_SLE                float64
# Cases_per_pop_AZE                float64
# Cases_per_pop_BES                float64
# Cases_per_pop_TUN                float64
# Cases_per_pop_JPN                float64
# Cases_per_pop_PNG                float64
# Cases_per_pop_AUT                float64
# Cases_per_pop_GGY                float64
# Cases_per_pop_JEY                float64
# Cases_per_pop_LUX                float64
# Cases_per_pop_KOR                float64
# Cases_per_pop_TUV                float64
# Cases_per_pop_LSO                float64
# Cases_per_pop_GUY                float64
# Cases_per_pop_BLZ                float64
# Cases_per_pop_CUB                float64
# Cases_per_pop_HUN                float64
# Cases_per_pop_LVA                float64
# Cases_per_pop_BIH                float64
# Cases_per_pop_DMA                float64
# Cases_per_pop_ROU                float64
# Cases_per_pop_OWID_EUR           float64
# Cases_per_pop_SGP                float64
# Cases_per_pop_VIR                float64
# Cases_per_pop_PRK                float64
# Cases_per_pop_MCO                float64
# Cases_per_pop_FRO                float64
# Cases_per_pop_ESP                float64
# Cases_per_pop_SMR                float64
# Cases_per_pop_ISR                float64
# Cases_per_pop_SVK                float64
# Cases_per_pop_MLI                float64
# Cases_per_pop_POL                float64
# Cases_per_pop_LBY                float64
# dtype: object

# %%
for i in df_per.columns[df_per.isnull().any(axis=0)]:     #---Applying Only on variables with NaN values
    df_per[i].fillna(df_per[i].mean(),inplace=True)

# %%
df_small.fillna(df_small.mean())
df_small.drop(df_small.head(100).index,inplace=True)
df_small.drop(df_small.tail(100).index,inplace=True)
# Out:
# <ipython-input-137-d28d2937dbbf>:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
df_per.set_index(0).rename(columns={0:'date'})
for each in country_list:
    l_vec = len(df_per['Cases_per_pop_'+each])
    X = np.arange(l_vec).reshape(-1, 1)
    y = np.log(np.array(df_per['Cases_per_pop_'+each]))
    y = y[np.logical_not(np.isnan(y))]    

    if y.shape[0]!=0:
        reg.fit(X, y)
        X_hat = np.arange(l_vec).reshape(-1, 1)
        Y_hat = reg.predict(X_hat)
        # LR_inspect = df_per[[0, 'Cases_per_pop_'+each]].copy()
        # LR_inspect['prediction'] = np.exp(Y_hat)
        LR_inspect =df_per[0].copy()
        LR_inspect = pd.concat[LR_inspect,df_per['Cases_per_pop_'+each]]
    else:
        pass
quick_plot(LR_inspect[0], LR_inspect.iloc[:, 1:], y_scale='log', slider=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-8d8e9fe96e85> in <module>
#      13         # LR_inspect['prediction'] = np.exp(Y_hat)
#      14         LR_inspect =df_per[0].copy()
# ---> 15         LR_inspect = pd.concat[LR_inspect,df_per['Cases_per_pop_'+each]]
#      16     else:
#      17         pass
#
# TypeError: 'function' object is not subscriptable

# %%
for each in country_list:
    l_vec = len(df_small['Cases_per_pop_'+each])
    X = np.arange(l_vec).reshape(-1, 1)
    y = np.log(np.array(df_small['Cases_per_pop_'+each][:]))
    reg.fit(X, y)
    X_hat = np.arange(l_vec).reshape(-1, 1)
    Y_hat = reg.predict(X_hat)
    LR_inspect = df_small[['date', 'Cases_per_pop_'+each]].copy()
    LR_inspect['prediction'] = np.exp(Y_hat)

    quick_plot(LR_inspect.date, LR_inspect.iloc[:, 1:], y_scale='log', slider=True)

# %% [markdown]
# # Doubling Rate - Piecewise Linear Regression

# %%
reg = linear_model.LinearRegression(fit_intercept=True)

# %%
for each in country_list:
    df_small['Cases_per_pop_'+each + '_filter'] = signal.savgol_filter(
            df_small['Cases_per_pop_'+each],
            19,  # window size used for filtering
            3)  # order of fitted polynomial
df_small

# %%
filter_cols = ['Cases_per_pop_AUS_filter', 'Cases_per_pop_USA_filter', 'Cases_per_pop_ESP_filter', 'Cases_per_pop_IND_filter', 'Cases_per_pop_CHN_filter', 'Cases_per_pop_DEU_filter', 'Cases_per_pop_AFG_filter']
start_pos = 0
quick_plot(df_list.date[start_pos:],
           df_list[filter_cols].iloc[start_pos:, :],
           y_scale='log',
           slider=True)

# %%
reg = linear_model.LinearRegression(fit_intercept=True)
l_vec=len(df_small['Cases_per_pop_AUS'])
X=np.arange(l_vec-50).reshape(-1,1)
y=np.array(df_small['Cases_per_pop_AUS'][50:])

# %%
reg.fit(X,y)

# %%
reg.intercept_

# %%
reg.coef_

# %%
def get_rate_via_regression(in_array):
    ''' Use a linear regression to approximate the doubling rate'''

    y = np.array(in_array)
    X = np.arange(2, 5).reshape(-1, 1) # Changed the np.arange(-1,2) to the current one

    # Check to ensure that the calculation is based only on 3 data points we use assert == 3.
    assert len(in_array) == 3

    reg.fit(X, y)
    intercept = reg.intercept_
    slope = reg.coef_
    return intercept / slope

# %%
df_small['Cases_per_pop_AUS_DR']=df_small['Cases_per_pop_AUS'].rolling(window=3, min_periods=3).apply(get_rate_via_regression)
df_small

# %%
quick_plot(df_small.date, df_small.iloc[40:,[15]], y_scale='linear')

# %%
def doubling_time(in_array):
    ''' Use a classical doubling time formular, 
     see https://en.wikipedia.org/wiki/Doubling_time '''
    y = np.array(in_array)
    return len(y) * np.log(2) / np.log(y[-1] / y[0])

# %%
df_small['AUS_DT']=df_small['Cases_per_pop_AUS'].rolling(window=3, min_periods=3).apply(doubling_time)

# %%
quick_plot(df_small.date, df_small.iloc[40:,[15,16]], y_scale='linear')

# %%
def doubling_time(in_array):
    ''' Use a classical doubling time formular, 
     see https://en.wikipedia.org/wiki/Doubling_time '''
    y = np.array(in_array)
    return len(y) * np.log(2) / np.log(y[-1] / y[0])


days_back = 3
for pos, country in enumerate(country_list):
    df_list[country + '_DR'] = df_list[country].rolling(
        window=days_back, min_periods=days_back).apply(get_rate_via_regression,
                                                       raw=False)
days_back = 3
for pos, country in enumerate(filter_cols):
    df_list[country + '_DR'] = df_list[country].rolling(
        window=days_back, min_periods=days_back).apply(get_rate_via_regression,
                                                       raw=False)
df_list['Germany_DR_math'] = df_list['Cases_per_pop_DEU'].rolling(
    window=days_back, min_periods=days_back).apply(doubling_time, raw=False)
days_back = 3
for pos, country in enumerate(filter_cols):
    df_list[country + '_DR'] = df_list[country].rolling(
        window=days_back, min_periods=days_back).apply(get_rate_via_regression,
                                                       raw=False)
df_list.columns
start_pos = 40
quick_plot(df_list.date,
           df_list.iloc[start_pos:, [11, 12, 13, 14]],
           y_scale='linear',
           slider=True)

# %%
start_pos = 40
quick_plot(df_list.date,
           df_list.iloc[start_pos:, [16, 17, 18, 19]],
           y_scale='linear',
           slider=True)
