# %%
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
import dash
import requests
import json

from IPython.display import clear_output
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Relative Cases (Absolute Covid Cases/Population Size)

# %%
# Requesting the Covid Cases data from our world in data website as a json object.
data_cases = requests.get(
    'https://covid.ourworldindata.org/data/owid-covid-data.json')

# Requesting the vaccination data from our world in data website as a json object:
data_Vax = requests.get(
    'https://github.com/owid/covid-19-data/raw/master/public/data/vaccinations/vaccinations.json'
)

# %%
# load json object for the total number of COVID cases
json_object_cases = json.loads(data_cases.content)

# Dumping all data from json into a variable:
json_object_vax = json.loads(data_Vax.content)

# %%
country_list = ['AUS', 'USA', 'ESP', 'IND']
for each in country_list:
    cases_country_data = json_object_cases[each]['data'][:]
    pop = json_object_cases[each]['population']
    print(pop)
# Out:
# 25921089.0
# 336997624.0
# 47486935.0
# 1407563842.0

# %%
# create an empty dictionary
dict_from_list = {}

# for loop to convert list of dict
# to dict of list
for item in json_object_vax:
    name = item['iso_code']
    dict_from_list[name] = item

dict_from_list['AUS']['data']
# Out:
# [{'date': '2021-02-21',
#   'total_vaccinations': 20,
#   'people_vaccinated': 20,
#   'total_vaccinations_per_hundred': 0.0,
#   'people_vaccinated_per_hundred': 0.0},
#  {'date': '2021-02-22',
#   'total_vaccinations': 2789,
#   'people_vaccinated': 2789,
#   'daily_vaccinations_raw': 2769,
#   'daily_vaccinations': 2769,
#   'total_vaccinations_per_hundred': 0.01,
#   'people_vaccinated_per_hundred': 0.01,
#   'daily_vaccinations_per_million': 107,
#   'daily_people_vaccinated': 2769,
#   'daily_people_vaccinated_per_hundred': 0.011},
#  {'date': '2021-02-23',
#   'total_vaccinations': 6914,
#   'people_vaccinated': 6911,
#   'people_fully_vaccinated': 3,
#   'daily_vaccinations_raw': 4125,
#   'daily_vaccinations': 3447,
#   'total_vaccinations_per_hundred': 0.03,
#   'people_vaccinated_per_hundred': 0.03,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 133,
#   'daily_people_vaccinated': 3446,
#   'daily_people_vaccinated_per_hundred': 0.013},
#  {'date': '2021-02-24',
#   'total_vaccinations': 16629,
#   'people_vaccinated': 16626,
#   'people_fully_vaccinated': 3,
#   'daily_vaccinations_raw': 9715,
#   'daily_vaccinations': 5536,
#   'total_vaccinations_per_hundred': 0.06,
#   'people_vaccinated_per_hundred': 0.06,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 214,
#   'daily_people_vaccinated': 5535,
#   'daily_people_vaccinated_per_hundred': 0.021},
#  {'date': '2021-02-25',
#   'total_vaccinations': 23510,
#   'people_vaccinated': 23501,
#   'people_fully_vaccinated': 9,
#   'daily_vaccinations_raw': 6881,
#   'daily_vaccinations': 5872,
#   'total_vaccinations_per_hundred': 0.09,
#   'people_vaccinated_per_hundred': 0.09,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 227,
#   'daily_people_vaccinated': 5870,
#   'daily_people_vaccinated_per_hundred': 0.023},
#  {'date': '2021-02-26',
#   'total_vaccinations': 30000,
#   'people_vaccinated': 29989,
#   'people_fully_vaccinated': 11,
#   'daily_vaccinations_raw': 6490,
#   'daily_vaccinations': 5996,
#   'total_vaccinations_per_hundred': 0.12,
#   'people_vaccinated_per_hundred': 0.12,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 231,
#   'daily_people_vaccinated': 5994,
#   'daily_people_vaccinated_per_hundred': 0.023},
#  {'date': '2021-02-27',
#   'total_vaccinations': 31894,
#   'people_vaccinated': 31882,
#   'people_fully_vaccinated': 12,
#   'daily_vaccinations_raw': 1894,
#   'daily_vaccinations': 5312,
#   'total_vaccinations_per_hundred': 0.12,
#   'people_vaccinated_per_hundred': 0.12,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 205,
#   'daily_people_vaccinated': 5310,
#   'daily_people_vaccinated_per_hundred': 0.02},
#  {'date': '2021-02-28',
#   'total_vaccinations': 34630,
#   'people_vaccinated': 34618,
#   'people_fully_vaccinated': 12,
#   'daily_vaccinations_raw': 2736,
#   'daily_vaccinations': 4944,
#   'total_vaccinations_per_hundred': 0.13,
#   'people_vaccinated_per_hundred': 0.13,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 191,
#   'daily_people_vaccinated': 4943,
#   'daily_people_vaccinated_per_hundred': 0.019},
#  {'date': '2021-03-01',
#   'total_vaccinations': 41907,
#   'people_vaccinated': 41895,
#   'people_fully_vaccinated': 12,
#   'daily_vaccinations_raw': 7277,
#   'daily_vaccinations': 5588,
#   'total_vaccinations_per_hundred': 0.16,
#   'people_vaccinated_per_hundred': 0.16,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 216,
#   'daily_people_vaccinated': 5587,
#   'daily_people_vaccinated_per_hundred': 0.022},
#  {'date': '2021-03-02',
#   'total_vaccinations': 51070,
#   'people_vaccinated': 51058,
#   'people_fully_vaccinated': 12,
#   'daily_vaccinations_raw': 9163,
#   'daily_vaccinations': 6308,
#   'total_vaccinations_per_hundred': 0.2,
#   'people_vaccinated_per_hundred': 0.2,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 243,
#   'daily_people_vaccinated': 6307,
#   'daily_people_vaccinated_per_hundred': 0.024},
#  {'date': '2021-03-03',
#   'total_vaccinations': 61009,
#   'people_vaccinated': 60994,
#   'people_fully_vaccinated': 15,
#   'daily_vaccinations_raw': 9939,
#   'daily_vaccinations': 6340,
#   'total_vaccinations_per_hundred': 0.24,
#   'people_vaccinated_per_hundred': 0.24,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 245,
#   'daily_people_vaccinated': 6338,
#   'daily_people_vaccinated_per_hundred': 0.024},
#  {'date': '2021-03-04',
#   'total_vaccinations': 71867,
#   'people_vaccinated': 71848,
#   'people_fully_vaccinated': 19,
#   'daily_vaccinations_raw': 10858,
#   'daily_vaccinations': 6908,
#   'total_vaccinations_per_hundred': 0.28,
#   'people_vaccinated_per_hundred': 0.28,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 267,
#   'daily_people_vaccinated': 6907,
#   'daily_people_vaccinated_per_hundred': 0.027},
#  {'date': '2021-03-05',
#   'total_vaccinations': 76940,
#   'people_vaccinated': 76916,
#   'people_fully_vaccinated': 24,
#   'daily_vaccinations_raw': 5073,
#   'daily_vaccinations': 6706,
#   'total_vaccinations_per_hundred': 0.3,
#   'people_vaccinated_per_hundred': 0.3,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 259,
#   'daily_people_vaccinated': 6704,
#   'daily_people_vaccinated_per_hundred': 0.026},
#  {'date': '2021-03-06',
#   'total_vaccinations': 81345,
#   'people_vaccinated': 81321,
#   'people_fully_vaccinated': 24,
#   'daily_vaccinations_raw': 4405,
#   'daily_vaccinations': 7064,
#   'total_vaccinations_per_hundred': 0.31,
#   'people_vaccinated_per_hundred': 0.31,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 273,
#   'daily_people_vaccinated': 7063,
#   'daily_people_vaccinated_per_hundred': 0.027},
#  {'date': '2021-03-07',
#   'total_vaccinations': 86369,
#   'people_vaccinated': 86345,
#   'people_fully_vaccinated': 24,
#   'daily_vaccinations_raw': 5024,
#   'daily_vaccinations': 7391,
#   'total_vaccinations_per_hundred': 0.33,
#   'people_vaccinated_per_hundred': 0.33,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 285,
#   'daily_people_vaccinated': 7390,
#   'daily_people_vaccinated_per_hundred': 0.029},
#  {'date': '2021-03-08',
#   'total_vaccinations': 94908,
#   'people_vaccinated': 94884,
#   'people_fully_vaccinated': 24,
#   'daily_vaccinations_raw': 8539,
#   'daily_vaccinations': 7572,
#   'total_vaccinations_per_hundred': 0.37,
#   'people_vaccinated_per_hundred': 0.37,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 292,
#   'daily_people_vaccinated': 7570,
#   'daily_people_vaccinated_per_hundred': 0.029},
#  {'date': '2021-03-09',
#   'total_vaccinations': 108328,
#   'people_vaccinated': 108301,
#   'people_fully_vaccinated': 27,
#   'daily_vaccinations_raw': 13420,
#   'daily_vaccinations': 8180,
#   'total_vaccinations_per_hundred': 0.42,
#   'people_vaccinated_per_hundred': 0.42,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 316,
#   'daily_people_vaccinated': 8178,
#   'daily_people_vaccinated_per_hundred': 0.032},
#  {'date': '2021-03-10',
#   'total_vaccinations': 125000,
#   'people_vaccinated': 124972,
#   'people_fully_vaccinated': 28,
#   'daily_vaccinations_raw': 16672,
#   'daily_vaccinations': 9142,
#   'total_vaccinations_per_hundred': 0.48,
#   'people_vaccinated_per_hundred': 0.48,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 353,
#   'daily_people_vaccinated': 9140,
#   'daily_people_vaccinated_per_hundred': 0.035},
#  {'date': '2021-03-11',
#   'total_vaccinations': 135109,
#   'people_vaccinated': 135077,
#   'people_fully_vaccinated': 32,
#   'daily_vaccinations_raw': 10109,
#   'daily_vaccinations': 9035,
#   'total_vaccinations_per_hundred': 0.52,
#   'people_vaccinated_per_hundred': 0.52,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 349,
#   'daily_people_vaccinated': 9033,
#   'daily_people_vaccinated_per_hundred': 0.035},
#  {'date': '2021-03-12',
#   'total_vaccinations': 159294,
#   'people_vaccinated': 159260,
#   'people_fully_vaccinated': 34,
#   'daily_vaccinations_raw': 24185,
#   'daily_vaccinations': 11765,
#   'total_vaccinations_per_hundred': 0.61,
#   'people_vaccinated_per_hundred': 0.61,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 454,
#   'daily_people_vaccinated': 11763,
#   'daily_people_vaccinated_per_hundred': 0.045},
#  {'date': '2021-03-13',
#   'total_vaccinations': 162551,
#   'people_vaccinated': 162517,
#   'people_fully_vaccinated': 34,
#   'daily_vaccinations_raw': 3257,
#   'daily_vaccinations': 11601,
#   'total_vaccinations_per_hundred': 0.63,
#   'people_vaccinated_per_hundred': 0.63,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 448,
#   'daily_people_vaccinated': 11599,
#   'daily_people_vaccinated_per_hundred': 0.045},
#  {'date': '2021-03-14',
#   'total_vaccinations': 164781,
#   'people_vaccinated': 164746,
#   'people_fully_vaccinated': 35,
#   'daily_vaccinations_raw': 2230,
#   'daily_vaccinations': 11202,
#   'total_vaccinations_per_hundred': 0.64,
#   'people_vaccinated_per_hundred': 0.64,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 432,
#   'daily_people_vaccinated': 11200,
#   'daily_people_vaccinated_per_hundred': 0.043},
#  {'date': '2021-03-15',
#   'total_vaccinations': 182437,
#   'people_vaccinated': 182214,
#   'people_fully_vaccinated': 223,
#   'daily_vaccinations_raw': 17656,
#   'daily_vaccinations': 12504,
#   'total_vaccinations_per_hundred': 0.7,
#   'people_vaccinated_per_hundred': 0.7,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 482,
#   'daily_people_vaccinated': 12476,
#   'daily_people_vaccinated_per_hundred': 0.048},
#  {'date': '2021-03-16',
#   'total_vaccinations': 203557,
#   'people_vaccinated': 203032,
#   'people_fully_vaccinated': 525,
#   'daily_vaccinations_raw': 21120,
#   'daily_vaccinations': 13604,
#   'total_vaccinations_per_hundred': 0.79,
#   'people_vaccinated_per_hundred': 0.78,
#   'people_fully_vaccinated_per_hundred': 0.0,
#   'daily_vaccinations_per_million': 525,
#   'daily_people_vaccinated': 13533,
#   'daily_people_vaccinated_per_hundred': 0.052},
#  {'date': '2021-03-17',
#   'total_vaccinations': 226057,
#   'people_vaccinated': 224711,
#   'people_fully_vaccinated': 1346,
#   'daily_vaccinations_raw': 22500,
#   'daily_vaccinations': 14437,
#   'total_vaccinations_per_hundred': 0.87,
#   'people_vaccinated_per_hundred': 0.87,
#   'people_fully_vaccinated_per_hundred': 0.01,
#   'daily_vaccinations_per_million': 557,
#   'daily_people_vaccinated': 14248,
#   'daily_people_vaccinated_per_hundred': 0.055},
#  {'date': '2021-03-18',
#   'total_vaccinations': 240754,
#   'people_vaccinated': 238673,
#   'people_fully_vaccinated': 2081,
#   'daily_vaccinations_raw': 14697,
#   'daily_vaccinations': 15092,
#   'total_vaccinations_per_hundred': 0.93,
#   'people_vaccinated_per_hundred': 0.92,
#   'people_fully_vaccinated_per_hundred': 0.01,
#   'daily_vaccinations_per_million': 582,
#   'daily_people_vaccinated': 14799,
#   'daily_people_vaccinated_per_hundred': 0.057},
#  {'date': '2021-03-19',
#   'total_vaccinations': 253831,
#   'people_vaccinated': 251060,
#   'people_fully_vaccinated': 2771,
#   'daily_vaccinations_raw': 13077,
#   'daily_vaccinations': 13505,
#   'total_vaccinations_per_hundred': 0.98,
#   'people_vaccinated_per_hundred': 0.97,
#   'people_fully_vaccinated_per_hundred': 0.01,
#   'daily_vaccinations_per_million': 521,
#   'daily_people_vaccinated': 13114,
#   'daily_people_vaccinated_per_hundred': 0.051},
#  {'date': '2021-03-20',
#   'total_vaccinations': 256782,
#   'people_vaccinated': 253858,
#   'people_fully_vaccinated': 2924,
#   'daily_vaccinations_raw': 2951,
#   'daily_vaccinations': 13462,
#   'total_vaccinations_per_hundred': 0.99,
#   'people_vaccinated_per_hundred': 0.98,
#   'people_fully_vaccinated_per_hundred': 0.01,
#   'daily_vaccinations_per_million': 519,
#   'daily_people_vaccinated': 13049,
#   'daily_people_vaccinated_per_hundred': 0.05},
#  {'date': '2021-03-21',
#   'total_vaccinations': 281960,
#   'people_vaccinated': 262283,
#   'people_fully_vaccinated': 19677,
#   'daily_vaccinations_raw': 25178,
#   'daily_vaccinations': 16740,
#   'total_vaccinations_per_hundred': 1.09,
#   'people_vaccinated_per_hundred': 1.01,
#   'people_fully_vaccinated_per_hundred': 0.08,
#   'daily_vaccinations_per_million': 646,
#   'daily_people_vaccinated': 13934,
#   'daily_people_vaccinated_per_hundred': 0.054},
#  {'date': '2021-03-22',
#   'total_vaccinations': 312502,
#   'people_vaccinated': 289317,
#   'people_fully_vaccinated': 23185,
#   'daily_vaccinations_raw': 30542,
#   'daily_vaccinations': 18581,
#   'total_vaccinations_per_hundred': 1.21,
#   'people_vaccinated_per_hundred': 1.12,
#   'people_fully_vaccinated_per_hundred': 0.09,
#   'daily_vaccinations_per_million': 717,
#   'daily_people_vaccinated': 15300,
#   'daily_people_vaccinated_per_hundred': 0.059},
#  {'date': '2021-03-23',
#   'total_vaccinations': 358502,
#   'people_vaccinated': 334123,
#   'people_fully_vaccinated': 24379,
#   'daily_vaccinations_raw': 46000,
#   'daily_vaccinations': 22135,
#   'total_vaccinations_per_hundred': 1.38,
#   'people_vaccinated_per_hundred': 1.29,
#   'people_fully_vaccinated_per_hundred': 0.09,
#   'daily_vaccinations_per_million': 854,
#   'daily_people_vaccinated': 18727,
#   'daily_people_vaccinated_per_hundred': 0.072},
#  {'date': '2021-03-24',
#   'total_vaccinations': 408410,
#   'people_vaccinated': 379837,
#   'people_fully_vaccinated': 28573,
#   'daily_vaccinations_raw': 49908,
#   'daily_vaccinations': 26050,
#   'total_vaccinations_per_hundred': 1.58,
#   'people_vaccinated_per_hundred': 1.47,
#   'people_fully_vaccinated_per_hundred': 0.11,
#   'daily_vaccinations_per_million': 1005,
#   'daily_people_vaccinated': 22161,
#   'daily_people_vaccinated_per_hundred': 0.085},
#  {'date': '2021-03-25',
#   'total_vaccinations': 460155,
#   'people_vaccinated': 427294,
#   'people_fully_vaccinated': 32861,
#   'daily_vaccinations_raw': 51745,
#   'daily_vaccinations': 31343,
#   'total_vaccinations_per_hundred': 1.78,
#   'people_vaccinated_per_hundred': 1.65,
#   'people_fully_vaccinated_per_hundred': 0.13,
#   'daily_vaccinations_per_million': 1209,
#   'daily_people_vaccinated': 26946,
#   'daily_people_vaccinated_per_hundred': 0.104},
#  {'date': '2021-03-26',
#   'total_vaccinations': 506465,
#   'people_vaccinated': 471771,
#   'people_fully_vaccinated': 34694,
#   'daily_vaccinations_raw': 46310,
#   'daily_vaccinations': 36091,
#   'total_vaccinations_per_hundred': 1.95,
#   'people_vaccinated_per_hundred': 1.82,
#   'people_fully_vaccinated_per_hundred': 0.13,
#   'daily_vaccinations_per_million': 1392,
#   'daily_people_vaccinated': 31530,
#   'daily_people_vaccinated_per_hundred': 0.122},
#  {'date': '2021-03-27',
#   'total_vaccinations': 524189,
#   'people_vaccinated': 488220,
#   'people_fully_vaccinated': 35969,
#   'daily_vaccinations_raw': 17724,
#   'daily_vaccinations': 38201,
#   'total_vaccinations_per_hundred': 2.02,
#   'people_vaccinated_per_hundred': 1.88,
#   'people_fully_vaccinated_per_hundred': 0.14,
#   'daily_vaccinations_per_million': 1474,
#   'daily_people_vaccinated': 33480,
#   'daily_people_vaccinated_per_hundred': 0.129},
#  {'date': '2021-03-28',
#   'total_vaccinations': 541761,
#   'people_vaccinated': 505085,
#   'people_fully_vaccinated': 36676,
#   'daily_vaccinations_raw': 17572,
#   'daily_vaccinations': 37114,
#   'total_vaccinations_per_hundred': 2.09,
#   'people_vaccinated_per_hundred': 1.95,
#   'people_fully_vaccinated_per_hundred': 0.14,
#   'daily_vaccinations_per_million': 1432,
#   'daily_people_vaccinated': 34686,
#   'daily_people_vaccinated_per_hundred': 0.134},
#  {'date': '2021-03-29',
#   'total_vaccinations': 597525,
#   'people_vaccinated': 551335,
#   'people_fully_vaccinated': 46190,
#   'daily_vaccinations_raw': 55764,
#   'daily_vaccinations': 40718,
#   'total_vaccinations_per_hundred': 2.31,
#   'people_vaccinated_per_hundred': 2.13,
#   'people_fully_vaccinated_per_hundred': 0.18,
#   'daily_vaccinations_per_million': 1571,
#   'daily_people_vaccinated': 37431,
#   'daily_people_vaccinated_per_hundred': 0.144},
#  {'date': '2021-03-30',
#   'total_vaccinations': 670351,
#   'people_vaccinated': 620336,
#   'people_fully_vaccinated': 50015,
#   'daily_vaccinations_raw': 72826,
#   'daily_vaccinations': 44550,
#   'total_vaccinations_per_hundred': 2.59,
#   'people_vaccinated_per_hundred': 2.39,
#   'people_fully_vaccinated_per_hundred': 0.19,
#   'daily_vaccinations_per_million': 1719,
#   'daily_people_vaccinated': 40888,
#   'daily_people_vaccinated_per_hundred': 0.158},
#  {'date': '2021-03-31',
#   'total_vaccinations': 744330,
#   'people_vaccinated': 671606,
#   'people_fully_vaccinated': 72724,
#   'daily_vaccinations_raw': 73979,
#   'daily_vaccinations': 47989,
#   'total_vaccinations_per_hundred': 2.87,
#   'people_vaccinated_per_hundred': 2.59,
#   'people_fully_vaccinated_per_hundred': 0.28,
#   'daily_vaccinations_per_million': 1851,
#   'daily_people_vaccinated': 41681,
#   'daily_people_vaccinated_per_hundred': 0.161},
#  {'date': '2021-04-01',
#   'total_vaccinations': 823613,
#   'people_vaccinated': 744369,
#   'people_fully_vaccinated': 79244,
#   'daily_vaccinations_raw': 79283,
#   'daily_vaccinations': 51923,
#   'total_vaccinations_per_hundred': 3.18,
#   'people_vaccinated_per_hundred': 2.87,
#   'people_fully_vaccinated_per_hundred': 0.31,
#   'daily_vaccinations_per_million': 2003,
#   'daily_people_vaccinated': 45296,
#   'daily_people_vaccinated_per_hundred': 0.175},
#  {'date': '2021-04-02',
#   'total_vaccinations': 828059,
#   'people_vaccinated': 747698,
#   'people_fully_vaccinated': 80361,
#   'daily_vaccinations_raw': 4446,
#   'daily_vaccinations': 45942,
#   'total_vaccinations_per_hundred': 3.19,
#   'people_vaccinated_per_hundred': 2.88,
#   'people_fully_vaccinated_per_hundred': 0.31,
#   'daily_vaccinations_per_million': 1772,
#   'daily_people_vaccinated': 39418,
#   'daily_people_vaccinated_per_hundred': 0.152},
#  {'date': '2021-04-03',
#   'total_vaccinations': 843182,
#   'people_vaccinated': 761864,
#   'people_fully_vaccinated': 81318,
#   'daily_vaccinations_raw': 15123,
#   'daily_vaccinations': 45570,
#   'total_vaccinations_per_hundred': 3.25,
#   'people_vaccinated_per_hundred': 2.94,
#   'people_fully_vaccinated_per_hundred': 0.31,
#   'daily_vaccinations_per_million': 1758,
#   'daily_people_vaccinated': 39092,
#   'daily_people_vaccinated_per_hundred': 0.151},
#  {'date': '2021-04-04',
#   'total_vaccinations': 844309,
#   'people_vaccinated': 762679,
#   'people_fully_vaccinated': 81630,
#   'daily_vaccinations_raw': 1127,
#   'daily_vaccinations': 43221,
#   'total_vaccinations_per_hundred': 3.26,
#   'people_vaccinated_per_hundred': 2.94,
#   'people_fully_vaccinated_per_hundred': 0.31,
#   'daily_vaccinations_per_million': 1667,
#   'daily_people_vaccinated': 36799,
#   'daily_people_vaccinated_per_hundred': 0.142},
#  {'date': '2021-04-05',
#   'total_vaccinations': 854983,
#   'people_vaccinated': 771972,
#   'people_fully_vaccinated': 83011,
#   'daily_vaccinations_raw': 10674,
#   'daily_vaccinations': 36780,
#   'total_vaccinations_per_hundred': 3.3,
#   'people_vaccinated_per_hundred': 2.98,
#   'people_fully_vaccinated_per_hundred': 0.32,
#   'daily_vaccinations_per_million': 1419,
#   'daily_people_vaccinated': 31520,
#   'daily_people_vaccinated_per_hundred': 0.122},
#  {'date': '2021-04-06',
#   'total_vaccinations': 920334,
#   'people_vaccinated': 829963,
#   'people_fully_vaccinated': 90371,
#   'daily_vaccinations_raw': 65351,
#   'daily_vaccinations': 35712,
#   'total_vaccinations_per_hundred': 3.55,
#   'people_vaccinated_per_hundred': 3.2,
#   'people_fully_vaccinated_per_hundred': 0.35,
#   'daily_vaccinations_per_million': 1378,
#   'daily_people_vaccinated': 29947,
#   'daily_people_vaccinated_per_hundred': 0.116},
#  {'date': '2021-04-07',
#   'total_vaccinations': 996214,
#   'people_vaccinated': 899641,
#   'people_fully_vaccinated': 96573,
#   'daily_vaccinations_raw': 75880,
#   'daily_vaccinations': 35983,
#   'total_vaccinations_per_hundred': 3.84,
#   'people_vaccinated_per_hundred': 3.47,
#   'people_fully_vaccinated_per_hundred': 0.37,
#   'daily_vaccinations_per_million': 1388,
#   'daily_people_vaccinated': 32576,
#   'daily_people_vaccinated_per_hundred': 0.126},
#  {'date': '2021-04-08',
#   'total_vaccinations': 1077511,
#   'people_vaccinated': 940239,
#   'people_fully_vaccinated': 137272,
#   'daily_vaccinations_raw': 81297,
#   'daily_vaccinations': 36271,
#   'total_vaccinations_per_hundred': 4.16,
#   'people_vaccinated_per_hundred': 3.63,
#   'people_fully_vaccinated_per_hundred': 0.53,
#   'daily_vaccinations_per_million': 1399,
#   'daily_people_vaccinated': 27981,
#   'daily_people_vaccinated_per_hundred': 0.108},
#  {'date': '2021-04-09',
#   'total_vaccinations': 1138866,
#   'people_vaccinated': 993668,
#   'people_fully_vaccinated': 145198,
#   'daily_vaccinations_raw': 61355,
#   'daily_vaccinations': 44401,
#   'total_vaccinations_per_hundred': 4.39,
#   'people_vaccinated_per_hundred': 3.83,
#   'people_fully_vaccinated_per_hundred': 0.56,
#   'daily_vaccinations_per_million': 1713,
#   'daily_people_vaccinated': 35139,
#   'daily_people_vaccinated_per_hundred': 0.136},
#  {'date': '2021-04-10',
#   'total_vaccinations': 1166568,
#   'people_vaccinated': 1018671,
#   'people_fully_vaccinated': 147897,
#   'daily_vaccinations_raw': 27702,
#   'daily_vaccinations': 46198,
#   'total_vaccinations_per_hundred': 4.5,
#   'people_vaccinated_per_hundred': 3.93,
#   'people_fully_vaccinated_per_hundred': 0.57,
#   'daily_vaccinations_per_million': 1782,
#   'daily_people_vaccinated': 36687,
#   'daily_people_vaccinated_per_hundred': 0.142},
#  {'date': '2021-04-11',
#   'total_vaccinations': 1178302,
#   'people_vaccinated': 1029486,
#   'people_fully_vaccinated': 148816,
#   'daily_vaccinations_raw': 11734,
#   'daily_vaccinations': 47713,
#   'total_vaccinations_per_hundred': 4.55,
#   'people_vaccinated_per_hundred': 3.97,
#   'people_fully_vaccinated_per_hundred': 0.57,
#   'daily_vaccinations_per_million': 1841,
#   'daily_people_vaccinated': 38115,
#   'daily_people_vaccinated_per_hundred': 0.147},
#  {'date': '2021-04-12',
#   'total_vaccinations': 1234681,
#   'people_vaccinated': 1077574,
#   'people_fully_vaccinated': 157107,
#   'daily_vaccinations_raw': 56379,
#   'daily_vaccinations': 54243,
#   'total_vaccinations_per_hundred': 4.76,
#   'people_vaccinated_per_hundred': 4.16,
#   'people_fully_vaccinated_per_hundred': 0.61,
#   'daily_vaccinations_per_million': 2093,
#   'daily_people_vaccinated': 43657,
#   'daily_people_vaccinated_per_hundred': 0.168},
#  {'date': '2021-04-13',
#   'total_vaccinations': 1295672,
#   'people_vaccinated': 1131621,
#   'people_fully_vaccinated': 164051,
#   'daily_vaccinations_raw': 60991,
#   'daily_vaccinations': 53620,
#   'total_vaccinations_per_hundred': 5.0,
#   'people_vaccinated_per_hundred': 4.37,
#   'people_fully_vaccinated_per_hundred': 0.63,
#   'daily_vaccinations_per_million': 2069,
#   'daily_people_vaccinated': 43094,
#   'daily_people_vaccinated_per_hundred': 0.166},
#  {'date': '2021-04-14',
#   'total_vaccinations': 1359305,
#   'people_vaccinated': 1188424,
#   'people_fully_vaccinated': 170881,
#   'daily_vaccinations_raw': 63633,
#   'daily_vaccinations': 51870,
#   'total_vaccinations_per_hundred': 5.24,
#   'people_vaccinated_per_hundred': 4.58,
#   'people_fully_vaccinated_per_hundred': 0.66,
#   'daily_vaccinations_per_million': 2001,
#   'daily_people_vaccinated': 41255,
#   'daily_people_vaccinated_per_hundred': 0.159},
#  {'date': '2021-04-15',
#   'total_vaccinations': 1420577,
#   'people_vaccinated': 1242588,
#   'people_fully_vaccinated': 177989,
#   'daily_vaccinations_raw': 61272,
#   'daily_vaccinations': 49009,
#   'total_vaccinations_per_hundred': 5.48,
#   'people_vaccinated_per_hundred': 4.79,
#   'people_fully_vaccinated_per_hundred': 0.69,
#   'daily_vaccinations_per_million': 1891,
#   'daily_people_vaccinated': 43193,
#   'daily_people_vaccinated_per_hundred': 0.167},
#  {'date': '2021-04-16',
#   'total_vaccinations': 1474558,
#   'people_vaccinated': 1290409,
#   'people_fully_vaccinated': 184149,
#   'daily_vaccinations_raw': 53981,
#   'daily_vaccinations': 47956,
#   'total_vaccinations_per_hundred': 5.69,
#   'people_vaccinated_per_hundred': 4.98,
#   'people_fully_vaccinated_per_hundred': 0.71,
#   'daily_vaccinations_per_million': 1850,
#   'daily_people_vaccinated': 42392,
#   'daily_people_vaccinated_per_hundred': 0.164},
#  {'date': '2021-04-17',
#   'total_vaccinations': 1496912,
#   'people_vaccinated': 1310866,
#   'people_fully_vaccinated': 186046,
#   'daily_vaccinations_raw': 22354,
#   'daily_vaccinations': 47192,
#   'total_vaccinations_per_hundred': 5.77,
#   'people_vaccinated_per_hundred': 5.06,
#   'people_fully_vaccinated_per_hundred': 0.72,
#   'daily_vaccinations_per_million': 1821,
#   'daily_people_vaccinated': 41742,
#   'daily_people_vaccinated_per_hundred': 0.161},
#  {'date': '2021-04-18',
#   'total_vaccinations': 1586556,
#   'people_vaccinated': 1399808,
#   'people_fully_vaccinated': 186748,
#   'daily_vaccinations_raw': 89644,
#   'daily_vaccinations': 58322,
#   'total_vaccinations_per_hundred': 6.12,
#   'people_vaccinated_per_hundred': 5.4,
#   'people_fully_vaccinated_per_hundred': 0.72,
#   'daily_vaccinations_per_million': 2250,
#   'daily_people_vaccinated': 52903,
#   'daily_people_vaccinated_per_hundred': 0.204},
#  {'date': '2021-04-19',
#   'total_vaccinations': 1653286,
#   'people_vaccinated': 1459097,
#   'people_fully_vaccinated': 194189,
#   'daily_vaccinations_raw': 66730,
#   'daily_vaccinations': 59801,
#   'total_vaccinations_per_hundred': 6.38,
#   'people_vaccinated_per_hundred': 5.63,
#   'people_fully_vaccinated_per_hundred': 0.75,
#   'daily_vaccinations_per_million': 2307,
#   'daily_people_vaccinated': 54503,
#   'daily_people_vaccinated_per_hundred': 0.21},
#  {'date': '2021-04-20',
#   'total_vaccinations': 1718107,
#   'people_vaccinated': 1516390,
#   'people_fully_vaccinated': 201717,
#   'daily_vaccinations_raw': 64821,
#   'daily_vaccinations': 60348,
#   'total_vaccinations_per_hundred': 6.63,
#   'people_vaccinated_per_hundred': 5.85,
#   'people_fully_vaccinated_per_hundred': 0.78,
#   'daily_vaccinations_per_million': 2328,
#   'daily_people_vaccinated': 54967,
#   'daily_people_vaccinated_per_hundred': 0.212},
#  {'date': '2021-04-21',
#   'total_vaccinations': 1785698,
#   'people_vaccinated': 1565322,
#   'people_fully_vaccinated': 220376,
#   'daily_vaccinations_raw': 67591,
#   'daily_vaccinations': 60913,
#   'total_vaccinations_per_hundred': 6.89,
#   'people_vaccinated_per_hundred': 6.04,
#   'people_fully_vaccinated_per_hundred': 0.85,
#   'daily_vaccinations_per_million': 2350,
#   'daily_people_vaccinated': 53843,
#   'daily_people_vaccinated_per_hundred': 0.208},
#  {'date': '2021-04-22',
#   'total_vaccinations': 1855601,
#   'people_vaccinated': 1628307,
#   'people_fully_vaccinated': 227294,
#   'daily_vaccinations_raw': 69903,
#   'daily_vaccinations': 62146,
#   'total_vaccinations_per_hundred': 7.16,
#   'people_vaccinated_per_hundred': 6.28,
#   'people_fully_vaccinated_per_hundred': 0.88,
#   'daily_vaccinations_per_million': 2398,
#   'daily_people_vaccinated': 55103,
#   'daily_people_vaccinated_per_hundred': 0.213},
#  {'date': '2021-04-23',
#   'total_vaccinations': 1914047,
#   'people_vaccinated': 1682424,
#   'people_fully_vaccinated': 231623,
#   'daily_vaccinations_raw': 58446,
#   'daily_vaccinations': 62784,
#   'total_vaccinations_per_hundred': 7.38,
#   'people_vaccinated_per_hundred': 6.49,
#   'people_fully_vaccinated_per_hundred': 0.89,
#   'daily_vaccinations_per_million': 2422,
#   'daily_people_vaccinated': 56002,
#   'daily_people_vaccinated_per_hundred': 0.216},
#  {'date': '2021-04-24',
#   'total_vaccinations': 1934077,
#   'people_vaccinated': 1701357,
#   'people_fully_vaccinated': 232720,
#   'daily_vaccinations_raw': 20030,
#   'daily_vaccinations': 62452,
#   'total_vaccinations_per_hundred': 7.46,
#   'people_vaccinated_per_hundred': 6.56,
#   'people_fully_vaccinated_per_hundred': 0.9,
#   'daily_vaccinations_per_million': 2409,
#   'daily_people_vaccinated': 55784,
#   'daily_people_vaccinated_per_hundred': 0.215},
#  {'date': '2021-04-25',
#   'total_vaccinations': 1937485,
#   'people_vaccinated': 1704743,
#   'people_fully_vaccinated': 232742,
#   'daily_vaccinations_raw': 3408,
#   'daily_vaccinations': 50133,
#   'total_vaccinations_per_hundred': 7.47,
#   'people_vaccinated_per_hundred': 6.58,
#   'people_fully_vaccinated_per_hundred': 0.9,
#   'daily_vaccinations_per_million': 1934,
#   'daily_people_vaccinated': 43562,
#   'daily_people_vaccinated_per_hundred': 0.168},
#  {'date': '2021-04-26',
#   'total_vaccinations': 1969337,
#   'people_vaccinated': 1735756,
#   'people_fully_vaccinated': 233581,
#   'daily_vaccinations_raw': 31852,
#   'daily_vaccinations': 45150,
#   'total_vaccinations_per_hundred': 7.6,
#   'people_vaccinated_per_hundred': 6.7,
#   'people_fully_vaccinated_per_hundred': 0.9,
#   'daily_vaccinations_per_million': 1742,
#   'daily_people_vaccinated': 39523,
#   'daily_people_vaccinated_per_hundred': 0.152},
#  {'date': '2021-04-27',
#   'total_vaccinations': 2029544,
#   'people_vaccinated': 1791020,
#   'people_fully_vaccinated': 238524,
#   'daily_vaccinations_raw': 60207,
#   'daily_vaccinations': 44491,
#   'total_vaccinations_per_hundred': 7.83,
#   'people_vaccinated_per_hundred': 6.91,
#   'people_fully_vaccinated_per_hundred': 0.92,
#   'daily_vaccinations_per_million': 1716,
#   'daily_people_vaccinated': 39233,
#   'daily_people_vaccinated_per_hundred': 0.151},
#  {'date': '2021-04-28',
#   'total_vaccinations': 2112285,
#   'people_vaccinated': 1867045,
#   'people_fully_vaccinated': 245240,
#   'daily_vaccinations_raw': 82741,
#   'daily_vaccinations': 46655,
#   'total_vaccinations_per_hundred': 8.15,
#   'people_vaccinated_per_hundred': 7.2,
#   'people_fully_vaccinated_per_hundred': 0.95,
#   'daily_vaccinations_per_million': 1800,
#   'daily_people_vaccinated': 43103,
#   'daily_people_vaccinated_per_hundred': 0.166},
#  {'date': '2021-04-29',
#   'total_vaccinations': 2179544,
#   'people_vaccinated': 1926672,
#   'people_fully_vaccinated': 252872,
#   'daily_vaccinations_raw': 67259,
#   'daily_vaccinations': 46278,
#   'total_vaccinations_per_hundred': 8.41,
#   'people_vaccinated_per_hundred': 7.43,
#   'people_fully_vaccinated_per_hundred': 0.98,
#   'daily_vaccinations_per_million': 1785,
#   'daily_people_vaccinated': 42624,
#   'daily_people_vaccinated_per_hundred': 0.164},
#  {'date': '2021-04-30',
#   'total_vaccinations': 2234844,
#   'people_vaccinated': 1976315,
#   'people_fully_vaccinated': 258529,
#   'daily_vaccinations_raw': 55300,
#   'daily_vaccinations': 45828,
#   'total_vaccinations_per_hundred': 8.62,
#   'people_vaccinated_per_hundred': 7.62,
#   'people_fully_vaccinated_per_hundred': 1.0,
#   'daily_vaccinations_per_million': 1768,
#   'daily_people_vaccinated': 41984,
#   'daily_people_vaccinated_per_hundred': 0.162},
#  {'date': '2021-05-01',
#   'total_vaccinations': 2254074,
#   'people_vaccinated': 1994063,
#   'people_fully_vaccinated': 260011,
#   'daily_vaccinations_raw': 19230,
#   'daily_vaccinations': 45714,
#   'total_vaccinations_per_hundred': 8.7,
#   'people_vaccinated_per_hundred': 7.69,
#   'people_fully_vaccinated_per_hundred': 1.0,
#   'daily_vaccinations_per_million': 1764,
#   'daily_people_vaccinated': 41815,
#   'daily_people_vaccinated_per_hundred': 0.161},
#  {'date': '2021-05-02',
#   'total_vaccinations': 2260615,
#   'people_vaccinated': 1999899,
#   'people_fully_vaccinated': 260716,
#   'daily_vaccinations_raw': 6541,
#   'daily_vaccinations': 46161,
#   'total_vaccinations_per_hundred': 8.72,
#   'people_vaccinated_per_hundred': 7.72,
#   'people_fully_vaccinated_per_hundred': 1.01,
#   'daily_vaccinations_per_million': 1781,
#   'daily_people_vaccinated': 42165,
#   'daily_people_vaccinated_per_hundred': 0.163},
#  {'date': '2021-05-03',
#   'total_vaccinations': 2316969,
#   'people_vaccinated': 2051573,
#   'people_fully_vaccinated': 265396,
#   'daily_vaccinations_raw': 56354,
#   'daily_vaccinations': 49662,
#   'total_vaccinations_per_hundred': 8.94,
#   'people_vaccinated_per_hundred': 7.91,
#   'people_fully_vaccinated_per_hundred': 1.02,
#   'daily_vaccinations_per_million': 1916,
#   'daily_people_vaccinated': 45117,
#   'daily_people_vaccinated_per_hundred': 0.174},
#  {'date': '2021-05-04',
#   'total_vaccinations': 2396314,
#   'people_vaccinated': 2124394,
#   'people_fully_vaccinated': 271920,
#   'daily_vaccinations_raw': 79345,
#   'daily_vaccinations': 52396,
#   'total_vaccinations_per_hundred': 9.24,
#   'people_vaccinated_per_hundred': 8.2,
#   'people_fully_vaccinated_per_hundred': 1.05,
#   'daily_vaccinations_per_million': 2021,
#   'daily_people_vaccinated': 47625,
#   'daily_people_vaccinated_per_hundred': 0.184},
#  {'date': '2021-05-05',
#   'total_vaccinations': 2473529,
#   'people_vaccinated': 2195139,
#   'people_fully_vaccinated': 278390,
#   'daily_vaccinations_raw': 77215,
#   'daily_vaccinations': 51606,
#   'total_vaccinations_per_hundred': 9.54,
#   'people_vaccinated_per_hundred': 8.47,
#   'people_fully_vaccinated_per_hundred': 1.07,
#   'daily_vaccinations_per_million': 1991,
#   'daily_people_vaccinated': 46871,
#   'daily_people_vaccinated_per_hundred': 0.181},
#  {'date': '2021-05-06',
#   'total_vaccinations': 2554531,
#   'people_vaccinated': 2268890,
#   'people_fully_vaccinated': 285641,
#   'daily_vaccinations_raw': 81002,
#   'daily_vaccinations': 53570,
#   'total_vaccinations_per_hundred': 9.86,
#   'people_vaccinated_per_hundred': 8.75,
#   'people_fully_vaccinated_per_hundred': 1.1,
#   'daily_vaccinations_per_million': 2067,
#   'daily_people_vaccinated': 48888,
#   'daily_people_vaccinated_per_hundred': 0.189},
#  {'date': '2021-05-07',
#   'total_vaccinations': 2627725,
#   'people_vaccinated': 2335211,
#   'people_fully_vaccinated': 292514,
#   'daily_vaccinations_raw': 73194,
#   'daily_vaccinations': 56126,
#   'total_vaccinations_per_hundred': 10.14,
#   'people_vaccinated_per_hundred': 9.01,
#   'people_fully_vaccinated_per_hundred': 1.13,
#   'daily_vaccinations_per_million': 2165,
#   'daily_people_vaccinated': 51271,
#   'daily_people_vaccinated_per_hundred': 0.198},
#  {'date': '2021-05-08',
#   'total_vaccinations': 2654338,
#   'people_vaccinated': 2360192,
#   'people_fully_vaccinated': 294146,
#   'daily_vaccinations_raw': 26613,
#   'daily_vaccinations': 57181,
#   'total_vaccinations_per_hundred': 10.24,
#   'people_vaccinated_per_hundred': 9.11,
#   'people_fully_vaccinated_per_hundred': 1.13,
#   'daily_vaccinations_per_million': 2206,
#   'daily_people_vaccinated': 52304,
#   'daily_people_vaccinated_per_hundred': 0.202},
#  {'date': '2021-05-09',
#   'total_vaccinations': 2663221,
#   'people_vaccinated': 2368476,
#   'people_fully_vaccinated': 294745,
#   'daily_vaccinations_raw': 8883,
#   'daily_vaccinations': 57515,
#   'total_vaccinations_per_hundred': 10.27,
#   'people_vaccinated_per_hundred': 9.14,
#   'people_fully_vaccinated_per_hundred': 1.14,
#   'daily_vaccinations_per_million': 2219,
#   'daily_people_vaccinated': 52654,
#   'daily_people_vaccinated_per_hundred': 0.203},
#  {'date': '2021-05-10',
#   'total_vaccinations': 2736107,
#   'people_vaccinated': 2436106,
#   'people_fully_vaccinated': 300001,
#   'daily_vaccinations_raw': 72886,
#   'daily_vaccinations': 59877,
#   'total_vaccinations_per_hundred': 10.56,
#   'people_vaccinated_per_hundred': 9.4,
#   'people_fully_vaccinated_per_hundred': 1.16,
#   'daily_vaccinations_per_million': 2310,
#   'daily_people_vaccinated': 54933,
#   'daily_people_vaccinated_per_hundred': 0.212},
#  {'date': '2021-05-11',
#   'total_vaccinations': 2812486,
#   'people_vaccinated': 2506399,
#   'people_fully_vaccinated': 306087,
#   'daily_vaccinations_raw': 76379,
#   'daily_vaccinations': 59453,
#   'total_vaccinations_per_hundred': 10.85,
#   'people_vaccinated_per_hundred': 9.67,
#   'people_fully_vaccinated_per_hundred': 1.18,
#   'daily_vaccinations_per_million': 2294,
#   'daily_people_vaccinated': 54572,
#   'daily_people_vaccinated_per_hundred': 0.211},
#  {'date': '2021-05-12',
#   'total_vaccinations': 2894770,
#   'people_vaccinated': 2580660,
#   'people_fully_vaccinated': 314110,
#   'daily_vaccinations_raw': 82284,
#   'daily_vaccinations': 60177,
#   'total_vaccinations_per_hundred': 11.17,
#   'people_vaccinated_per_hundred': 9.96,
#   'people_fully_vaccinated_per_hundred': 1.21,
#   'daily_vaccinations_per_million': 2322,
#   'daily_people_vaccinated': 55074,
#   'daily_people_vaccinated_per_hundred': 0.212},
#  {'date': '2021-05-13',
#   'total_vaccinations': 2980644,
#   'people_vaccinated': 2660509,
#   'people_fully_vaccinated': 320135,
#   'daily_vaccinations_raw': 85874,
#   'daily_vaccinations': 60873,
#   'total_vaccinations_per_hundred': 11.5,
#   'people_vaccinated_per_hundred': 10.26,
#   'people_fully_vaccinated_per_hundred': 1.24,
#   'daily_vaccinations_per_million': 2348,
#   'daily_people_vaccinated': 55946,
#   'daily_people_vaccinated_per_hundred': 0.216},
#  {'date': '2021-05-14',
#   'total_vaccinations': 3056797,
#   'people_vaccinated': 2728447,
#   'people_fully_vaccinated': 328350,
#   'daily_vaccinations_raw': 76153,
#   'daily_vaccinations': 61296,
#   'total_vaccinations_per_hundred': 11.79,
#   'people_vaccinated_per_hundred': 10.53,
#   'people_fully_vaccinated_per_hundred': 1.27,
#   'daily_vaccinations_per_million': 2365,
#   'daily_people_vaccinated': 56177,
#   'daily_people_vaccinated_per_hundred': 0.217},
#  {'date': '2021-05-15',
#   'total_vaccinations': 3089184,
#   'people_vaccinated': 2758361,
#   'people_fully_vaccinated': 330823,
#   'daily_vaccinations_raw': 32387,
#   'daily_vaccinations': 62121,
#   'total_vaccinations_per_hundred': 11.92,
#   'people_vaccinated_per_hundred': 10.64,
#   'people_fully_vaccinated_per_hundred': 1.28,
#   'daily_vaccinations_per_million': 2397,
#   'daily_people_vaccinated': 56881,
#   'daily_people_vaccinated_per_hundred': 0.219},
#  {'date': '2021-05-16',
#   'total_vaccinations': 3100137,
#   'people_vaccinated': 2768527,
#   'people_fully_vaccinated': 331610,
#   'daily_vaccinations_raw': 10953,
#   'daily_vaccinations': 62417,
#   'total_vaccinations_per_hundred': 11.96,
#   'people_vaccinated_per_hundred': 10.68,
#   'people_fully_vaccinated_per_hundred': 1.28,
#   'daily_vaccinations_per_million': 2408,
#   'daily_people_vaccinated': 57150,
#   'daily_people_vaccinated_per_hundred': 0.22},
#  {'date': '2021-05-17',
#   'total_vaccinations': 3183324,
#   'people_vaccinated': 2772593,
#   'people_fully_vaccinated': 410731,
#   'daily_vaccinations_raw': 83187,
#   'daily_vaccinations': 63888,
#   'total_vaccinations_per_hundred': 12.28,
#   'people_vaccinated_per_hundred': 10.7,
#   'people_fully_vaccinated_per_hundred': 1.58,
#   'daily_vaccinations_per_million': 2465,
#   'daily_people_vaccinated': 48070,
#   'daily_people_vaccinated_per_hundred': 0.185},
#  {'date': '2021-05-18',
#   'total_vaccinations': 3278854,
#   'people_vaccinated': 2861133,
#   'people_fully_vaccinated': 417721,
#   'daily_vaccinations_raw': 95530,
#   'daily_vaccinations': 66624,
#   'total_vaccinations_per_hundred': 12.65,
#   'people_vaccinated_per_hundred': 11.04,
#   'people_fully_vaccinated_per_hundred': 1.61,
#   'daily_vaccinations_per_million': 2570,
#   'daily_people_vaccinated': 50676,
#   'daily_people_vaccinated_per_hundred': 0.196},
#  {'date': '2021-05-19',
#   'total_vaccinations': 3371728,
#   'people_vaccinated': 2946301,
#   'people_fully_vaccinated': 425427,
#   'daily_vaccinations_raw': 92874,
#   'daily_vaccinations': 68137,
#   'total_vaccinations_per_hundred': 13.01,
#   'people_vaccinated_per_hundred': 11.37,
#   'people_fully_vaccinated_per_hundred': 1.64,
#   'daily_vaccinations_per_million': 2629,
#   'daily_people_vaccinated': 52234,
#   'daily_people_vaccinated_per_hundred': 0.202},
#  {'date': '2021-05-20',
#   'total_vaccinations': 3472874,
#   'people_vaccinated': 3038105,
#   'people_fully_vaccinated': 434769,
#   'daily_vaccinations_raw': 101146,
#   'daily_vaccinations': 70319,
#   'total_vaccinations_per_hundred': 13.4,
#   'people_vaccinated_per_hundred': 11.72,
#   'people_fully_vaccinated_per_hundred': 1.68,
#   'daily_vaccinations_per_million': 2713,
#   'daily_people_vaccinated': 53942,
#   'daily_people_vaccinated_per_hundred': 0.208},
#  {'date': '2021-05-21',
#   'total_vaccinations': 3562495,
#   'people_vaccinated': 3120757,
#   'daily_vaccinations_raw': 89621,
#   'daily_vaccinations': 72243,
#   'total_vaccinations_per_hundred': 13.74,
#   'people_vaccinated_per_hundred': 12.04,
#   'daily_vaccinations_per_million': 2787,
#   'daily_people_vaccinated': 56044,
#   'daily_people_vaccinated_per_hundred': 0.216},
#  {'date': '2021-05-22',
#   'total_vaccinations': 3599964,
#   'people_vaccinated': 3156107,
#   'daily_vaccinations_raw': 37469,
#   'daily_vaccinations': 72969,
#   'total_vaccinations_per_hundred': 13.89,
#   'people_vaccinated_per_hundred': 12.18,
#   'daily_vaccinations_per_million': 2815,
#   'daily_people_vaccinated': 56821,
#   'daily_people_vaccinated_per_hundred': 0.219},
#  {'date': '2021-05-23',
#   'total_vaccinations': 3613053,
#   'people_vaccinated': 3168814,
#   'daily_vaccinations_raw': 13089,
#   'daily_vaccinations': 73274,
#   'total_vaccinations_per_hundred': 13.94,
#   'people_vaccinated_per_hundred': 12.22,
#   'daily_vaccinations_per_million': 2827,
#   'daily_people_vaccinated': 57184,
#   'daily_people_vaccinated_per_hundred': 0.221},
#  {'date': '2021-05-24',
#   'total_vaccinations': 3690622,
#   'people_vaccinated': 3255437,
#   'people_fully_vaccinated': 435185,
#   'daily_vaccinations_raw': 77569,
#   'daily_vaccinations': 72471,
#   'total_vaccinations_per_hundred': 14.24,
#   'people_vaccinated_per_hundred': 12.56,
#   'people_fully_vaccinated_per_hundred': 1.68,
#   'daily_vaccinations_per_million': 2796,
#   'daily_people_vaccinated': 68978,
#   'daily_people_vaccinated_per_hundred': 0.266},
#  {'date': '2021-05-25',
#   'total_vaccinations': 3795280,
#   'people_vaccinated': 3320569,
#   'people_fully_vaccinated': 474711,
#   'daily_vaccinations_raw': 104658,
#   'daily_vaccinations': 73775,
#   'total_vaccinations_per_hundred': 14.64,
#   'people_vaccinated_per_hundred': 12.81,
#   'people_fully_vaccinated_per_hundred': 1.83,
#   'daily_vaccinations_per_million': 2846,
#   'daily_people_vaccinated': 65634,
#   'daily_people_vaccinated_per_hundred': 0.253},
#  {'date': '2021-05-26',
#   'total_vaccinations': 3906668,
#   'people_vaccinated': 3425248,
#   'people_fully_vaccinated': 481420,
#   'daily_vaccinations_raw': 111388,
#   'daily_vaccinations': 76420,
#   'total_vaccinations_per_hundred': 15.07,
#   'people_vaccinated_per_hundred': 13.21,
#   'people_fully_vaccinated_per_hundred': 1.86,
#   'daily_vaccinations_per_million': 2948,
#   'daily_people_vaccinated': 68421,
#   'daily_people_vaccinated_per_hundred': 0.264},
#  {'date': '2021-05-27',
#   'total_vaccinations': 4031539,
#   'people_vaccinated': 3541569,
#   'people_fully_vaccinated': 489970,
#   'daily_vaccinations_raw': 124871,
#   'daily_vaccinations': 79809,
#   'total_vaccinations_per_hundred': 15.55,
#   'people_vaccinated_per_hundred': 13.66,
#   'people_fully_vaccinated_per_hundred': 1.89,
#   'daily_vaccinations_per_million': 3079,
#   'daily_people_vaccinated': 71923,
#   'daily_people_vaccinated_per_hundred': 0.277},
#  {'date': '2021-05-28',
#   'total_vaccinations': 4153149,
#   'people_vaccinated': 3655905,
#   'people_fully_vaccinated': 497244,
#   'daily_vaccinations_raw': 121610,
#   'daily_vaccinations': 84379,
#   'total_vaccinations_per_hundred': 16.02,
#   'people_vaccinated_per_hundred': 14.1,
#   'people_fully_vaccinated_per_hundred': 1.92,
#   'daily_vaccinations_per_million': 3255,
#   'daily_people_vaccinated': 76450,
#   'daily_people_vaccinated_per_hundred': 0.295},
#  {'date': '2021-05-29',
#   'total_vaccinations': 4212899,
#   'people_vaccinated': 3714197,
#   'people_fully_vaccinated': 498702,
#   'daily_vaccinations_raw': 59750,
#   'daily_vaccinations': 87562,
#   'total_vaccinations_per_hundred': 16.25,
#   'people_vaccinated_per_hundred': 14.33,
#   'people_fully_vaccinated_per_hundred': 1.92,
#   'daily_vaccinations_per_million': 3378,
#   'daily_people_vaccinated': 79727,
#   'daily_people_vaccinated_per_hundred': 0.308},
#  {'date': '2021-05-30',
#   'total_vaccinations': 4243600,
#   'people_vaccinated': 3743622,
#   'people_fully_vaccinated': 499978,
#   'daily_vaccinations_raw': 30701,
#   'daily_vaccinations': 90078,
#   'total_vaccinations_per_hundred': 16.37,
#   'people_vaccinated_per_hundred': 14.44,
#   'people_fully_vaccinated_per_hundred': 1.93,
#   'daily_vaccinations_per_million': 3475,
#   'daily_people_vaccinated': 82115,
#   'daily_people_vaccinated_per_hundred': 0.317},
#  {'date': '2021-05-31',
#   'total_vaccinations': 4362739,
#   'people_vaccinated': 3856485,
#   'people_fully_vaccinated': 506254,
#   'daily_vaccinations_raw': 119139,
#   'daily_vaccinations': 96017,
#   'total_vaccinations_per_hundred': 16.83,
#   'people_vaccinated_per_hundred': 14.88,
#   'people_fully_vaccinated_per_hundred': 1.95,
#   'daily_vaccinations_per_million': 3704,
#   'daily_people_vaccinated': 85864,
#   'daily_people_vaccinated_per_hundred': 0.331},
#  {'date': '2021-06-01',
#   'total_vaccinations': 4501444,
#   'people_vaccinated': 3960329,
#   'people_fully_vaccinated': 541115,
#   'daily_vaccinations_raw': 138705,
#   'daily_vaccinations': 100881,
#   'total_vaccinations_per_hundred': 17.37,
#   'people_vaccinated_per_hundred': 15.28,
#   'people_fully_vaccinated_per_hundred': 2.09,
#   'daily_vaccinations_per_million': 3892,
#   'daily_people_vaccinated': 91394,
#   'daily_people_vaccinated_per_hundred': 0.353},
#  {'date': '2021-06-02',
#   'total_vaccinations': 4642703,
#   'people_vaccinated': 4092509,
#   'people_fully_vaccinated': 550194,
#   'daily_vaccinations_raw': 141259,
#   'daily_vaccinations': 105148,
#   'total_vaccinations_per_hundred': 17.91,
#   'people_vaccinated_per_hundred': 15.79,
#   'people_fully_vaccinated_per_hundred': 2.12,
#   'daily_vaccinations_per_million': 4056,
#   'daily_people_vaccinated': 95323,
#   'daily_people_vaccinated_per_hundred': 0.368},
#  {'date': '2021-06-03',
#   'total_vaccinations': 4786362,
#   'people_vaccinated': 4226528,
#   'people_fully_vaccinated': 559834,
#   'daily_vaccinations_raw': 143659,
#   'daily_vaccinations': 107832,
#   'total_vaccinations_per_hundred': 18.47,
#   'people_vaccinated_per_hundred': 16.31,
#   'people_fully_vaccinated_per_hundred': 2.16,
#   'daily_vaccinations_per_million': 4160,
#   'daily_people_vaccinated': 97851,
#   'daily_people_vaccinated_per_hundred': 0.377},
#  {'date': '2021-06-04',
#   'total_vaccinations': 4927607,
#   'people_vaccinated': 4357962,
#   'people_fully_vaccinated': 569645,
#   'daily_vaccinations_raw': 141245,
#   'daily_vaccinations': 110637,
#   'total_vaccinations_per_hundred': 19.01,
#   'people_vaccinated_per_hundred': 16.81,
#   'people_fully_vaccinated_per_hundred': 2.2,
#   'daily_vaccinations_per_million': 4268,
#   'daily_people_vaccinated': 100294,
#   'daily_people_vaccinated_per_hundred': 0.387},
#  {'date': '2021-06-05',
#   'total_vaccinations': 5016352,
#   'people_vaccinated': 4442925,
#   'people_fully_vaccinated': 573427,
#   'daily_vaccinations_raw': 88745,
#   'daily_vaccinations': 114779,
#   'total_vaccinations_per_hundred': 19.35,
#   'people_vaccinated_per_hundred': 17.14,
#   'people_fully_vaccinated_per_hundred': 2.21,
#   'daily_vaccinations_per_million': 4428,
#   'daily_people_vaccinated': 104104,
#   'daily_people_vaccinated_per_hundred': 0.402},
#  {'date': '2021-06-06',
#   'total_vaccinations': 5076413,
#   'people_vaccinated': 4463413,
#   'people_fully_vaccinated': 613000,
#   'daily_vaccinations_raw': 60061,
#   'daily_vaccinations': 118973,
#   'total_vaccinations_per_hundred': 19.58,
#   'people_vaccinated_per_hundred': 17.22,
#   'people_fully_vaccinated_per_hundred': 2.36,
#   'daily_vaccinations_per_million': 4590,
#   'daily_people_vaccinated': 102827,
#   'daily_people_vaccinated_per_hundred': 0.397},
#  {'date': '2021-06-07',
#   'total_vaccinations': 5203977,
#   'people_vaccinated': 4568516,
#   'people_fully_vaccinated': 635461,
#   'daily_vaccinations_raw': 127564,
#   'daily_vaccinations': 120177,
#   'total_vaccinations_per_hundred': 20.08,
#   'people_vaccinated_per_hundred': 17.62,
#   'people_fully_vaccinated_per_hundred': 2.45,
#   'daily_vaccinations_per_million': 4636,
#   'daily_people_vaccinated': 101719,
#   'daily_people_vaccinated_per_hundred': 0.392},
#  {'date': '2021-06-08',
#   'total_vaccinations': 5344862,
#   'people_vaccinated': 4693030,
#   'people_fully_vaccinated': 651832,
#   'daily_vaccinations_raw': 140885,
#   'daily_vaccinations': 120488,
#   'total_vaccinations_per_hundred': 20.62,
#   'people_vaccinated_per_hundred': 18.11,
#   'people_fully_vaccinated_per_hundred': 2.51,
#   'daily_vaccinations_per_million': 4648,
#   'daily_people_vaccinated': 104672,
#   'daily_people_vaccinated_per_hundred': 0.404},
#  {'date': '2021-06-09',
#   'total_vaccinations': 5487670,
#   'people_vaccinated': 4817746,
#   'people_fully_vaccinated': 669924,
#   'daily_vaccinations_raw': 142808,
#   'daily_vaccinations': 120710,
#   'total_vaccinations_per_hundred': 21.17,
#   'people_vaccinated_per_hundred': 18.59,
#   'people_fully_vaccinated_per_hundred': 2.58,
#   'daily_vaccinations_per_million': 4657,
#   'daily_people_vaccinated': 103605,
# ...
#   'daily_people_vaccinated': 669,
#   'daily_people_vaccinated_per_hundred': 0.003},
#  {'date': '2022-06-14',
#   'total_vaccinations': 57774642,
#   'people_vaccinated': 22335032,
#   'people_fully_vaccinated': 21641140,
#   'total_boosters': 13798470,
#   'daily_vaccinations_raw': 15563,
#   'daily_vaccinations': 8477,
#   'total_vaccinations_per_hundred': 222.89,
#   'people_vaccinated_per_hundred': 86.17,
#   'people_fully_vaccinated_per_hundred': 83.49,
#   'total_boosters_per_hundred': 53.23,
#   'daily_vaccinations_per_million': 327,
#   'daily_people_vaccinated': 1011,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-15',
#   'total_vaccinations': 57785001,
#   'people_fully_vaccinated': 21643147,
#   'total_boosters': 13805639,
#   'daily_vaccinations_raw': 10359,
#   'daily_vaccinations': 8279,
#   'total_vaccinations_per_hundred': 222.93,
#   'people_fully_vaccinated_per_hundred': 83.5,
#   'total_boosters_per_hundred': 53.26,
#   'daily_vaccinations_per_million': 319,
#   'daily_people_vaccinated': 899,
#   'daily_people_vaccinated_per_hundred': 0.003},
#  {'date': '2022-06-16',
#   'total_vaccinations': 57792674,
#   'people_vaccinated': 22336042,
#   'people_fully_vaccinated': 21643777,
#   'total_boosters': 13812855,
#   'daily_vaccinations_raw': 7673,
#   'daily_vaccinations': 7643,
#   'total_vaccinations_per_hundred': 222.96,
#   'people_vaccinated_per_hundred': 86.17,
#   'people_fully_vaccinated_per_hundred': 83.5,
#   'total_boosters_per_hundred': 53.29,
#   'daily_vaccinations_per_million': 295,
#   'daily_people_vaccinated': 782,
#   'daily_people_vaccinated_per_hundred': 0.003},
#  {'date': '2022-06-17',
#   'total_vaccinations': 57806676,
#   'people_vaccinated': 22338902,
#   'people_fully_vaccinated': 21647523,
#   'total_boosters': 13820251,
#   'daily_vaccinations_raw': 14002,
#   'daily_vaccinations': 8005,
#   'total_vaccinations_per_hundred': 223.01,
#   'people_vaccinated_per_hundred': 86.18,
#   'people_fully_vaccinated_per_hundred': 83.51,
#   'total_boosters_per_hundred': 53.32,
#   'daily_vaccinations_per_million': 309,
#   'daily_people_vaccinated': 1160,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-18',
#   'total_vaccinations': 57812219,
#   'people_vaccinated': 22339650,
#   'people_fully_vaccinated': 21649102,
#   'total_boosters': 13823467,
#   'daily_vaccinations_raw': 5543,
#   'daily_vaccinations': 7966,
#   'total_vaccinations_per_hundred': 223.03,
#   'people_vaccinated_per_hundred': 86.18,
#   'people_fully_vaccinated_per_hundred': 83.52,
#   'total_boosters_per_hundred': 53.33,
#   'daily_vaccinations_per_million': 307,
#   'daily_people_vaccinated': 1236,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-06-19',
#   'daily_vaccinations': 8655,
#   'daily_vaccinations_per_million': 334,
#   'daily_people_vaccinated': 1321,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-06-20',
#   'total_vaccinations': 57824481,
#   'people_vaccinated': 22341262,
#   'people_fully_vaccinated': 21651661,
#   'total_boosters': 13831558,
#   'daily_vaccinations': 9343,
#   'total_vaccinations_per_hundred': 223.08,
#   'people_vaccinated_per_hundred': 86.19,
#   'people_fully_vaccinated_per_hundred': 83.53,
#   'total_boosters_per_hundred': 53.36,
#   'daily_vaccinations_per_million': 360,
#   'daily_people_vaccinated': 1405,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-06-21',
#   'total_vaccinations': 57834650,
#   'people_vaccinated': 22342422,
#   'people_fully_vaccinated': 21653540,
#   'total_boosters': 13838688,
#   'daily_vaccinations_raw': 10169,
#   'daily_vaccinations': 8573,
#   'total_vaccinations_per_hundred': 223.12,
#   'people_vaccinated_per_hundred': 86.19,
#   'people_fully_vaccinated_per_hundred': 83.54,
#   'total_boosters_per_hundred': 53.39,
#   'daily_vaccinations_per_million': 331,
#   'daily_people_vaccinated': 1056,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-22',
#   'total_vaccinations': 57844431,
#   'people_vaccinated': 22343597,
#   'people_fully_vaccinated': 21655459,
#   'total_boosters': 13845375,
#   'daily_vaccinations_raw': 9781,
#   'daily_vaccinations': 8490,
#   'total_vaccinations_per_hundred': 223.16,
#   'people_vaccinated_per_hundred': 86.2,
#   'people_fully_vaccinated_per_hundred': 83.54,
#   'total_boosters_per_hundred': 53.41,
#   'daily_vaccinations_per_million': 328,
#   'daily_people_vaccinated': 1151,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-23',
#   'total_vaccinations': 57855260,
#   'people_vaccinated': 22344930,
#   'people_fully_vaccinated': 21657600,
#   'total_boosters': 13852730,
#   'daily_vaccinations_raw': 10829,
#   'daily_vaccinations': 8941,
#   'total_vaccinations_per_hundred': 223.2,
#   'people_vaccinated_per_hundred': 86.2,
#   'people_fully_vaccinated_per_hundred': 83.55,
#   'total_boosters_per_hundred': 53.44,
#   'daily_vaccinations_per_million': 345,
#   'daily_people_vaccinated': 1270,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-06-24',
#   'total_vaccinations': 57865526,
#   'people_vaccinated': 22346251,
#   'people_fully_vaccinated': 21659860,
#   'total_boosters': 13859415,
#   'daily_vaccinations_raw': 10266,
#   'daily_vaccinations': 8407,
#   'total_vaccinations_per_hundred': 223.24,
#   'people_vaccinated_per_hundred': 86.21,
#   'people_fully_vaccinated_per_hundred': 83.56,
#   'total_boosters_per_hundred': 53.47,
#   'daily_vaccinations_per_million': 324,
#   'daily_people_vaccinated': 1050,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-25',
#   'total_vaccinations': 57870645,
#   'people_vaccinated': 22347032,
#   'people_fully_vaccinated': 21661378,
#   'total_boosters': 13862235,
#   'daily_vaccinations_raw': 5119,
#   'daily_vaccinations': 8347,
#   'total_vaccinations_per_hundred': 223.26,
#   'people_vaccinated_per_hundred': 86.21,
#   'people_fully_vaccinated_per_hundred': 83.57,
#   'total_boosters_per_hundred': 53.48,
#   'daily_vaccinations_per_million': 322,
#   'daily_people_vaccinated': 1055,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-26',
#   'total_vaccinations': 57873254,
#   'people_vaccinated': 22347391,
#   'people_fully_vaccinated': 21662163,
#   'total_boosters': 13863700,
#   'daily_vaccinations_raw': 2609,
#   'daily_vaccinations': 7843,
#   'total_vaccinations_per_hundred': 223.27,
#   'people_vaccinated_per_hundred': 86.21,
#   'people_fully_vaccinated_per_hundred': 83.57,
#   'total_boosters_per_hundred': 53.48,
#   'daily_vaccinations_per_million': 303,
#   'daily_people_vaccinated': 991,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-27',
#   'total_vaccinations': 57883324,
#   'people_vaccinated': 22348768,
#   'people_fully_vaccinated': 21664352,
#   'total_boosters': 13870204,
#   'daily_vaccinations_raw': 10070,
#   'daily_vaccinations': 8406,
#   'total_vaccinations_per_hundred': 223.31,
#   'people_vaccinated_per_hundred': 86.22,
#   'people_fully_vaccinated_per_hundred': 83.58,
#   'total_boosters_per_hundred': 53.51,
#   'daily_vaccinations_per_million': 324,
#   'daily_people_vaccinated': 1072,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-28',
#   'total_vaccinations': 57893550,
#   'people_vaccinated': 22350120,
#   'people_fully_vaccinated': 21666494,
#   'total_boosters': 13876936,
#   'daily_vaccinations_raw': 10226,
#   'daily_vaccinations': 8414,
#   'total_vaccinations_per_hundred': 223.35,
#   'people_vaccinated_per_hundred': 86.22,
#   'people_fully_vaccinated_per_hundred': 83.59,
#   'total_boosters_per_hundred': 53.54,
#   'daily_vaccinations_per_million': 325,
#   'daily_people_vaccinated': 1100,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-29',
#   'total_vaccinations': 57903864,
#   'people_vaccinated': 22351411,
#   'people_fully_vaccinated': 21668833,
#   'total_boosters': 13883620,
#   'daily_vaccinations_raw': 10314,
#   'daily_vaccinations': 8490,
#   'total_vaccinations_per_hundred': 223.39,
#   'people_vaccinated_per_hundred': 86.23,
#   'people_fully_vaccinated_per_hundred': 83.6,
#   'total_boosters_per_hundred': 53.56,
#   'daily_vaccinations_per_million': 328,
#   'daily_people_vaccinated': 1116,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-06-30',
#   'total_vaccinations': 57914239,
#   'people_vaccinated': 22352755,
#   'people_fully_vaccinated': 21671067,
#   'total_boosters': 13890417,
#   'daily_vaccinations_raw': 10375,
#   'daily_vaccinations': 8426,
#   'total_vaccinations_per_hundred': 223.43,
#   'people_vaccinated_per_hundred': 86.23,
#   'people_fully_vaccinated_per_hundred': 83.6,
#   'total_boosters_per_hundred': 53.59,
#   'daily_vaccinations_per_million': 325,
#   'daily_people_vaccinated': 1118,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-01',
#   'total_vaccinations': 57923662,
#   'people_vaccinated': 22353997,
#   'people_fully_vaccinated': 21673357,
#   'total_boosters': 13896308,
#   'daily_vaccinations_raw': 9423,
#   'daily_vaccinations': 8305,
#   'total_vaccinations_per_hundred': 223.46,
#   'people_vaccinated_per_hundred': 86.24,
#   'people_fully_vaccinated_per_hundred': 83.61,
#   'total_boosters_per_hundred': 53.61,
#   'daily_vaccinations_per_million': 320,
#   'daily_people_vaccinated': 1107,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-02',
#   'total_vaccinations': 57927802,
#   'people_vaccinated': 22354539,
#   'people_fully_vaccinated': 21674563,
#   'total_boosters': 13898700,
#   'daily_vaccinations_raw': 4140,
#   'daily_vaccinations': 8165,
#   'total_vaccinations_per_hundred': 223.48,
#   'people_vaccinated_per_hundred': 86.24,
#   'people_fully_vaccinated_per_hundred': 83.62,
#   'total_boosters_per_hundred': 53.62,
#   'daily_vaccinations_per_million': 315,
#   'daily_people_vaccinated': 1072,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-03',
#   'daily_vaccinations': 8634,
#   'daily_vaccinations_per_million': 333,
#   'daily_people_vaccinated': 1150,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-04',
#   'total_vaccinations': 57939579,
#   'people_vaccinated': 22356344,
#   'people_fully_vaccinated': 21677442,
#   'total_boosters': 13905793,
#   'daily_vaccinations': 8036,
#   'total_vaccinations_per_hundred': 223.52,
#   'people_vaccinated_per_hundred': 86.25,
#   'people_fully_vaccinated_per_hundred': 83.63,
#   'total_boosters_per_hundred': 53.65,
#   'daily_vaccinations_per_million': 310,
#   'daily_people_vaccinated': 1082,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-05',
#   'total_vaccinations': 57950651,
#   'people_vaccinated': 22357868,
#   'people_fully_vaccinated': 21680053,
#   'total_boosters': 13912730,
#   'daily_vaccinations_raw': 11072,
#   'daily_vaccinations': 8157,
#   'total_vaccinations_per_hundred': 223.57,
#   'people_vaccinated_per_hundred': 86.25,
#   'people_fully_vaccinated_per_hundred': 83.64,
#   'total_boosters_per_hundred': 53.67,
#   'daily_vaccinations_per_million': 315,
#   'daily_people_vaccinated': 1107,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-06',
#   'total_vaccinations': 57962147,
#   'people_vaccinated': 22359392,
#   'people_fully_vaccinated': 21682635,
#   'total_boosters': 13920120,
#   'daily_vaccinations_raw': 11496,
#   'daily_vaccinations': 8326,
#   'total_vaccinations_per_hundred': 223.61,
#   'people_vaccinated_per_hundred': 86.26,
#   'people_fully_vaccinated_per_hundred': 83.65,
#   'total_boosters_per_hundred': 53.7,
#   'daily_vaccinations_per_million': 321,
#   'daily_people_vaccinated': 1140,
#   'daily_people_vaccinated_per_hundred': 0.004},
#  {'date': '2022-07-07',
#   'total_vaccinations': 57974604,
#   'people_vaccinated': 22361029,
#   'people_fully_vaccinated': 21685242,
#   'total_boosters': 13928333,
#   'daily_vaccinations_raw': 12457,
#   'daily_vaccinations': 8624,
#   'total_vaccinations_per_hundred': 223.66,
#   'people_vaccinated_per_hundred': 86.27,
#   'people_fully_vaccinated_per_hundred': 83.66,
#   'total_boosters_per_hundred': 53.73,
#   'daily_vaccinations_per_million': 333,
#   'daily_people_vaccinated': 1182,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-08',
#   'total_vaccinations': 57988175,
#   'people_vaccinated': 22362824,
#   'people_fully_vaccinated': 21688239,
#   'total_boosters': 13937112,
#   'daily_vaccinations_raw': 13571,
#   'daily_vaccinations': 9216,
#   'total_vaccinations_per_hundred': 223.71,
#   'people_vaccinated_per_hundred': 86.27,
#   'people_fully_vaccinated_per_hundred': 83.67,
#   'total_boosters_per_hundred': 53.77,
#   'daily_vaccinations_per_million': 356,
#   'daily_people_vaccinated': 1261,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-09',
#   'total_vaccinations': 57993505,
#   'people_vaccinated': 22363600,
#   'people_fully_vaccinated': 21689556,
#   'total_boosters': 13940349,
#   'daily_vaccinations_raw': 5330,
#   'daily_vaccinations': 9386,
#   'total_vaccinations_per_hundred': 223.73,
#   'people_vaccinated_per_hundred': 86.28,
#   'people_fully_vaccinated_per_hundred': 83.68,
#   'total_boosters_per_hundred': 53.78,
#   'daily_vaccinations_per_million': 362,
#   'daily_people_vaccinated': 1294,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-10',
#   'total_vaccinations': 57995534,
#   'people_vaccinated': 22363868,
#   'people_fully_vaccinated': 21689974,
#   'total_boosters': 13941692,
#   'daily_vaccinations_raw': 2029,
#   'daily_vaccinations': 8835,
#   'total_vaccinations_per_hundred': 223.74,
#   'people_vaccinated_per_hundred': 86.28,
#   'people_fully_vaccinated_per_hundred': 83.68,
#   'total_boosters_per_hundred': 53.79,
#   'daily_vaccinations_per_million': 341,
#   'daily_people_vaccinated': 1204,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-11',
#   'total_vaccinations': 58008153,
#   'people_vaccinated': 22365574,
#   'people_fully_vaccinated': 21692507,
#   'total_boosters': 13950072,
#   'daily_vaccinations_raw': 12619,
#   'daily_vaccinations': 9796,
#   'total_vaccinations_per_hundred': 223.79,
#   'people_vaccinated_per_hundred': 86.28,
#   'people_fully_vaccinated_per_hundred': 83.69,
#   'total_boosters_per_hundred': 53.82,
#   'daily_vaccinations_per_million': 378,
#   'daily_people_vaccinated': 1319,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-12',
#   'total_vaccinations': 58022127,
#   'people_vaccinated': 22367460,
#   'people_fully_vaccinated': 21695074,
#   'total_boosters': 13959593,
#   'daily_vaccinations_raw': 13974,
#   'daily_vaccinations': 10211,
#   'total_vaccinations_per_hundred': 223.84,
#   'people_vaccinated_per_hundred': 86.29,
#   'people_fully_vaccinated_per_hundred': 83.7,
#   'total_boosters_per_hundred': 53.85,
#   'daily_vaccinations_per_million': 394,
#   'daily_people_vaccinated': 1370,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-13',
#   'total_vaccinations': 58036155,
#   'people_vaccinated': 22369312,
#   'people_fully_vaccinated': 21697565,
#   'total_boosters': 13969278,
#   'daily_vaccinations_raw': 14028,
#   'daily_vaccinations': 10573,
#   'total_vaccinations_per_hundred': 223.9,
#   'people_vaccinated_per_hundred': 86.3,
#   'people_fully_vaccinated_per_hundred': 83.71,
#   'total_boosters_per_hundred': 53.89,
#   'daily_vaccinations_per_million': 408,
#   'daily_people_vaccinated': 1417,
#   'daily_people_vaccinated_per_hundred': 0.005},
#  {'date': '2022-07-14',
#   'total_vaccinations': 58050700,
#   'people_vaccinated': 22371315,
#   'people_fully_vaccinated': 21700230,
#   'total_boosters': 13979155,
#   'daily_vaccinations_raw': 14545,
#   'daily_vaccinations': 10871,
#   'total_vaccinations_per_hundred': 223.95,
#   'people_vaccinated_per_hundred': 86.31,
#   'people_fully_vaccinated_per_hundred': 83.72,
#   'total_boosters_per_hundred': 53.93,
#   'daily_vaccinations_per_million': 419,
#   'daily_people_vaccinated': 1469,
#   'daily_people_vaccinated_per_hundred': 0.006},
#  {'date': '2022-07-15',
#   'total_vaccinations': 58065619,
#   'people_vaccinated': 22373371,
#   'people_fully_vaccinated': 21703148,
#   'total_boosters': 13989100,
#   'daily_vaccinations_raw': 14919,
#   'daily_vaccinations': 11063,
#   'total_vaccinations_per_hundred': 224.01,
#   'people_vaccinated_per_hundred': 86.31,
#   'people_fully_vaccinated_per_hundred': 83.73,
#   'total_boosters_per_hundred': 53.97,
#   'daily_vaccinations_per_million': 427,
#   'daily_people_vaccinated': 1507,
#   'daily_people_vaccinated_per_hundred': 0.006}]

# %%
country_list = ['AUS', 'USA', 'ESP', 'IND']
for each in country_list:

    # Separating dictonary of USA from list and adding it to new list:
    country_vax_data = dict_from_list[each]['data'][:]

    # Separating the list that contains the data we need from the USA dictonary:

    # Creating an empty dictonary to get data(date, vaccination):
    dictionary_of_USA_date_vax = {}

    # Creating dictonary from the list:
    for item in country_vax_data:
        name = item['date']
        dictionary_of_USA_date_vax[name] = item

    # Creating an empty list:
    inter_list_USA = []

    # Adding all the keys from data dictonary to an empty list:
    for key in dictionary_of_USA_date_vax:
        inter_list_USA.append(dictionary_of_USA_date_vax[key])
# Out:
# 547

# %%
country_list = ['AUS', 'USA', 'ESP', 'IND']
dict_country = {}
# output=pd.DataFrame()
for each in country_list:
    cases_country_data = json_object_cases[each]['data'][:]
    dict_country['list_date_' + each] = []
    dict_country['list_cases_' + each] = []
    for index in range(len(cases_country_data)):
        # Obtaining the dates from the json dictionary
        list_date = json_object_cases[each]['data'][index]
        # append the dates to the date list
        dict_country['list_date_' + each].append(list_date['date'])

        # Get the total population for australia
        pop = json_object_cases[each]['population']

        list_cases = json_object_cases[each]['data'][index]
        dict_country['list_cases_' + each].append(list_cases['total_cases'] /
                                                  pop)

df = pd.DataFrame.from_dict(dict_country, orient='index').transpose()

for each in country_list:
    df['list_date_' + each] = pd.to_datetime(df['list_date_' + each],
                                             format='%Y-%m-%d')

df
# Out:
#     list_date_AUS list_cases_AUS list_date_USA list_cases_USA list_date_ESP  \
# 0      2020-01-26            0.0    2020-01-22            0.0    2020-02-01
# 1      2020-01-27            0.0    2020-01-23            0.0    2020-02-02
# 2      2020-01-28            0.0    2020-01-24            0.0    2020-02-03
# 3      2020-01-29            0.0    2020-01-25            0.0    2020-02-04
# 4      2020-01-30            0.0    2020-01-26            0.0    2020-02-05
# ..            ...            ...           ...            ...           ...
# 901    2022-07-15       0.336968    2022-07-11       0.263491           NaT
# 902           NaT           None    2022-07-12       0.263937           NaT
# 903           NaT           None    2022-07-13       0.264539           NaT
# 904           NaT           None    2022-07-14        0.26497           NaT
# 905           NaT           None    2022-07-15       0.265441           NaT
#
#     list_cases_ESP list_date_IND list_cases_IND
# 0              0.0    2020-01-30            0.0
# 1              0.0    2020-01-31            0.0
# 2              0.0    2020-02-01            0.0
# 3              0.0    2020-02-02            0.0
# 4              0.0    2020-02-03            0.0
# ..             ...           ...            ...
# 901           None           NaT           None
# 902           None           NaT           None
# 903           None           NaT           None
# 904           None           NaT           None
# 905           None           NaT           None
#
# [906 rows x 8 columns]

# %%
full_list = []
for each in country_list:
    country = each
    for pos, each_dict in enumerate(json_object_cases[country]['data'][:]):
        full_list.append(each_dict)

df_huge = pd.DataFrame(full_list)
df_huge.drop(df_huge.iloc[:, 2:], axis=1, inplace=True)
df_huge
# Out:
#             date  total_cases
# 0     2020-01-26          4.0
# 1     2020-01-27          5.0
# 2     2020-01-28          5.0
# 3     2020-01-29          6.0
# 4     2020-01-30          9.0
# ...          ...          ...
# 3597  2022-07-11   43652944.0
# 3598  2022-07-12   43669850.0
# 3599  2022-07-13   43689989.0
# 3600  2022-07-14   43710027.0
# 3601  2022-07-15   43710027.0
#
# [3602 rows x 2 columns]

# %%
df_huge = df_huge.shape[0]
df_huge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-b8510ea911ef> in <module>
# ----> 1 df_huge=df_huge.shape[0]
#       2 df_huge
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
list_data = []
for each in country_list:
    cases_country_data = json_object_cases[each]['data'][:]
    pd_cases_data = pd.DataFrame(cases_country_data)

# %%
sudo_date = []
for each in country_list:
    cases_country_data = json_object_cases[each]['data'][:]
    for index in range(len(cases_country_data)):
        # Obtaining the dates from the json dictionary
        list_date = json_object_cases[each]['data'][index]
        # append the dates to the date list
        sudo_date.append(list_date['date'])

        df_dates = pd.DataFrame(sudo_date)

df_dates[0] = pd.to_datetime(df_dates[0], format='%Y-%m-%d')
df_dates.drop_duplicates(keep="last", inplace=True)

df_dates
# Out:
#               0
# 902  2020-01-22
# 903  2020-01-23
# 904  2020-01-24
# 905  2020-01-25
# 906  2020-01-26
# ...         ...
# 3597 2022-07-11
# 3598 2022-07-12
# 3599 2022-07-13
# 3600 2022-07-14
# 3601 2022-07-15
#
# [906 rows x 1 columns]

# %%
df.insert(0, 'date', '')
print(df)
# Out:
#     date list_date_AUS list_cases_AUS list_date_USA list_cases_USA  \
# 0           2020-01-26            0.0    2020-01-22            0.0
# 1           2020-01-27            0.0    2020-01-23            0.0
# 2           2020-01-28            0.0    2020-01-24            0.0
# 3           2020-01-29            0.0    2020-01-25            0.0
# 4           2020-01-30            0.0    2020-01-26            0.0
# ..   ...           ...            ...           ...            ...
# 901         2022-07-15       0.336968    2022-07-11       0.263491
# 902                NaT           None    2022-07-12       0.263937
# 903                NaT           None    2022-07-13       0.264539
# 904                NaT           None    2022-07-14        0.26497
# 905                NaT           None    2022-07-15       0.265441
#
#     list_date_ESP list_cases_ESP list_date_IND list_cases_IND
# 0      2020-02-01            0.0    2020-01-30            0.0
# 1      2020-02-02            0.0    2020-01-31            0.0
# 2      2020-02-03            0.0    2020-02-01            0.0
# 3      2020-02-04            0.0    2020-02-02            0.0
# 4      2020-02-05            0.0    2020-02-03            0.0
# ..            ...            ...           ...            ...
# 901           NaT           None           NaT           None
# 902           NaT           None           NaT           None
# 903           NaT           None           NaT           None
# 904           NaT           None           NaT           None
# 905           NaT           None           NaT           None
#
# [906 rows x 9 columns]

# %%
grouped_cases = df.groupby('list_date_AUS').list_cases_AUS.sum()
print(grouped_cases)
# Out:
# list_date_AUS
# 2020-01-26         0.0
# 2020-01-27         0.0
# 2020-01-28         0.0
# 2020-01-29         0.0
# 2020-01-30         0.0
#                 ...
# 2022-07-11    0.330294
# 2022-07-12    0.332007
# 2022-07-13    0.333824
# 2022-07-14     0.33532
# 2022-07-15    0.336968
# Name: list_cases_AUS, Length: 902, dtype: object

# %%
# Defining the size for plotting
fig = plt.figure(figsize=(16, 9))
for each in country_list:
    clear_output(wait=True)
    plt.plot(df['list_date_' + each],
             df['list_cases_' + each],
             label=each + "_cases")

# Add X-label for date
plt.xlabel('Date')
# Add Y-label for relative covid cases
plt.ylabel('Relative COVID Cases (Absolute Cases/Total Population)')
# Add legend
plt.legend()
# Display Plot
plt.show()

# %% [markdown]
# # Relative Vaccinations (Absolute Vaccination/Population Size)

# %%
# create an empty dictionary
dict_from_list = {}

# for loop to convert list of dict
# to dict of list
for item in json_object_vax:
    name = item['iso_code']
    dict_from_list[name] = item

for each in country_list:
    dict_from_list[each]

    # Separating dictonary of USA from list and adding it to new list:
    country_USA = dict_from_list[each]

    # Separating the list that contains the data we need from the USA dictonary:
    country_USA_data = dict_from_list[each]['data']

    # Creating an empty dictonary to get data(date, vaccination):
    dictionary_of_USA_date_vax = {}

    # Creating dictonary from the list:
    for item in country_USA_data:
        name = item['date']
        dictionary_of_USA_date_vax[name] = item

    # Creating an empty list:
    inter_list_USA = []

    # Adding all the keys from data dictonary to an empty list:
    for key in dictionary_of_USA_date_vax:
        inter_list_USA.append(dictionary_of_USA_date_vax[key])

    # Converting list to dataframe:
    pd_USA_inter = pd.DataFrame(inter_list_USA)

    # Renaming the label total_vaccinations column to 'USA ratio vaccination:population' (data it holds while plotting)
    pd_USA_inter = pd_USA_inter.rename(
        columns={'total_vaccinations': 'USA_ratio_vax_pop'})

    # Setting the index of the dataframe to date:
    pd_USA_inter.set_index('date')

    # Separating the data columns that we need for the plot (date, total_vaccinations):
    pd_USA_fin = pd_USA_inter.iloc[:, [0, 1]]

    # Get the total population for australia
    pop = json_object_cases[each]['population']

    # Dividing the vaccinated people by total population to get the ratio:
    fin_USA = pd_USA_fin.copy()
    fin_USA['USA_ratio_vax_pop'] = fin_USA['USA_ratio_vax_pop'].div(pop)

# %%
# Defining the size for plotting
fig = plt.figure(figsize=(16, 9))
for each in country_list:
    clear_output(wait=True)
    plt.plot(df['list_date_' + each],
             df['list_cases_' + each],
             label=each + "_cases")

# Add X-label for date
plt.xlabel('Date')
# Add Y-label for relative covid cases
plt.ylabel('Relative Vaccination(Total Vaccination/Total Population)')
# Add legend
plt.legend()
# Display Plot
plt.show()

# %%
# create an empty dictionary
dict_from_list = {}

# for loop to convert list of dict
# to dict of list
for item in json_object_vax:
    name = item['country']
    dict_from_list[name] = item

# Separating dictonary of USA from list and adding it to new list:
country_USA = dict_from_list['United States']

# Separating the list that contains the data we need from the USA dictonary:
country_USA_data = country_USA['data']

# Creating an empty dictonary to get data(date, vaccination):
dictionary_of_USA_date_vax = {}

# Creating dictonary from the list:
for item in country_USA_data:
    name = item['date']
    dictionary_of_USA_date_vax[name] = item

# Creating an empty list:
inter_list_USA = []

# Adding all the keys from data dictonary to an empty list:
for key in dictionary_of_USA_date_vax:
    inter_list_USA.append(dictionary_of_USA_date_vax[key])

# Converting list to dataframe:
pd_USA_inter = pd.DataFrame(inter_list_USA)

# Renaming the label total_vaccinations column to 'USA ratio vaccination:population' (data it holds while plotting)
pd_USA_inter = pd_USA_inter.rename(
    columns={'total_vaccinations': 'USA_ratio_vax_pop'})

# Setting the index of the dataframe to date:
pd_USA_inter.set_index('date')

# Separating the data columns that we need for the plot (date, total_vaccinations):
pd_USA_fin = pd_USA_inter.iloc[:, [0, 1]]

# Getting the total population of United Kingdom from the above requested json data:
pop_USA = json_object_cases['USA']['population']

# Dividing the vaccinated people by total population to get the ratio:
fin_USA = pd_USA_fin.copy()
fin_USA['USA_ratio_vax_pop'] = fin_USA['USA_ratio_vax_pop'].div(pop_USA)

# %% [markdown]
# # Dashboard Creation

# %%
app = dash.Dash()
app.layout = html.Div([
    html.Label('Multi-Select Country'),
    dcc.Dropdown(id='country_drop_down',
                 options=[{
                     'label': 'Australia',
                     'value': 'AUS'
                 }, {
                     'label': 'USA',
                     'value': 'USA'
                 }, {
                     'label': 'Spain',
                     'value': 'ESP'
                 }, {
                     'label': 'India',
                     'value': 'IND'
                 }],
                 value=['USA', 'IND'],
                 multi=True),
    dcc.Graph(figure=fig, id='main_window_slope')
])

# %%
@app.callback(Output('main_window_slope', 'figure'),
              [Input('country_drop_down', 'value')])
def update_figure(country_list):

    traces = []
    for each in country_list:
        traces.append(
            dict(x=df.date,
                 y=df[each],
                 mode='markers+lines',
                 opacity=0.9,
                 line_width=2,
                 marker_size=1,
                 name=each))

    return {
        'data':
        traces,
        'layout':
        dict(
            width=1280,
            height=720,
            xaxis_title='Time',
            yaxis_title='Confirmed infected people (source johns hopkins case, log-scale)',
            xaxis={
                'tickangle': -45,
                'nticks': 20,
                'tickfont': dict(size=14, color='#7f7f7f'),
            },
            yaxis={
                'type': 'log',
                'range': '[1.1, 5.5]'
            })
    }

# %%
app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
